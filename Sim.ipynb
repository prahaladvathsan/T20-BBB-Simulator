# %%
# Cell 1: Imports and setup
import json
import os
import sys
import csv
import pandas as pd
from datetime import datetime, timedelta
import random
from typing import Dict, List, Tuple, Any

# Only add this if needed for module imports
import sys
sys.path.append('..')  # or appropriate path

from src.utils.data_loader import DataLoader
from src.models.player import Player
from src.models.team import Team
from src.models.match import Match

class LeagueSimulator:
    """
    Simulates a complete T20 cricket league using real team and player data.
    """
    
    def __init__(self, data_dir: str = "data"):
        """Initialize the league simulator with data directory."""
        self.data_dir = data_dir
        self.loader = DataLoader(data_dir)
        self.linked_data = None
        self.player_objects = {}
        self.team_objects = {}
        self.league_results = []
        self.load_data()
        
    def load_data(self):
        """Load all required data for simulation."""
        print("Loading data...")
        self.linked_data = self.loader.load_comprehensive_data()
        
        # Create player objects
        for player_id, player_data in self.linked_data['players'].items():
            self.player_objects[player_id] = Player(player_id, player_data)
        
        # Create team objects
        i = 0
        for team_id, team_data in self.linked_data['teams'].items():
            print(team_id, team_data)
            self.team_objects[team_id] = Team(team_id, team_data, self.player_objects)
            
        print(f"Loaded data for {len(self.team_objects)} teams and {len(self.player_objects)} players")
        
    def create_match_schedule(self) -> List[Tuple[str, str]]:
        """Create a round-robin tournament schedule."""
        teams = list(self.team_objects.keys())
        matches = []
        
        # Round-robin scheduling (each team plays against every other team)
        for i in range(len(teams)):
            for j in range(i + 1, len(teams)):
                matches.append((teams[i], teams[j]))
        
        # Randomize the order of matches
        random.shuffle(matches)
        return matches
    
    def simulate_league(self):
        """Simulate all matches in the league and record results."""
            
        matches = self.create_match_schedule()
        total_matches = len(matches)
        
        print(f"\nStarting league simulation with {total_matches} matches...")
        
        # Create output directory for BBB data if it doesn't exist
        os.makedirs("output/matches", exist_ok=True)
        
        # Initialize BBB dataset
        self._initialize_bbb_dataset()
        
        for match_num, (team1_id, team2_id) in enumerate(matches, 1):
            print(f"\nSimulating match {match_num}/{total_matches}: {team1_id} vs {team2_id}")
            
            team1 = self.team_objects[team1_id]
            team2 = self.team_objects[team2_id]
            
            # Get venue data
            venues = list(self.linked_data['venues'].keys())
            venue_id = random.choice(venues)
            
            # Match date (simulating a league over the number of matches)
            match_date = (datetime.now() - timedelta(days=total_matches-match_num)).strftime('%Y-%m-%d')
            
            # Create and simulate match
            match = Match(team1, team2, match_id=f"match{match_num}", venue_id=venue_id, match_date=match_date)
            match_results = match.simulate_match()
            
            # Display match scorecard
            self.display_match_scorecard(match_results)
            
            # Get BBB data and append to dataset
            bbb_data = match_results.get('bbb_data', [])
            self._append_to_bbb_dataset(bbb_data)
            
            # Store match results
            winner_name = match_results['result']['winner']
            winner_id = team1_id if winner_name == team1.name else team2_id
            
            self.league_results.append({
                'match_num': match_num,
                'team1': team1_id,
                'team2': team2_id,
                'winner': winner_id,
                'margin': match_results['result']['margin'],
                'margin_type': match_results.get('margin_type', 'runs' if match_results['innings'][1]['batting_team'] == winner_name else 'wickets')
            })
            
        return self.league_results
    
    def _initialize_bbb_dataset(self):
        """Initialize the ball-by-ball dataset structure."""
        fieldnames = [
            'match_id', 'match_date', 'venue_id', 'innings', 'over', 'ball',
            'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
            'runs', 'is_wicket', 'outcome', 'line', 'length', 'phase'
        ]
        
        csv_path = "output/matches/t20_bbb.csv"
        with open(csv_path, 'w', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
    
    def _append_to_bbb_dataset(self, bbb_data: List[Dict]):
        """Append new ball-by-ball data to the dataset."""
        if not bbb_data:
            return
            
        csv_path = "output/matches/t20_bbb.csv"
        
        with open(csv_path, 'a', newline='') as csvfile:
            fieldnames = [
                'match_id', 'match_date', 'venue_id', 'innings', 'over', 'ball',
                'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
                'runs', 'is_wicket', 'outcome', 'line', 'length', 'phase'
            ]
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writerows(bbb_data)
    
    def calculate_standings(self) -> List[Tuple[str, Dict]]:
        """Calculate league standings from match results."""
        standings = {}
        
        for team_id in self.team_objects.keys():
            standings[team_id] = {
                'played': 0, 'won': 0, 'lost': 0, 
                'points': 0, 'nrr': 0.0
            }
        
        for match in self.league_results:
            team1 = match['team1']
            team2 = match['team2']
            winner = match['winner']
            
            # Update match count
            standings[team1]['played'] += 1
            standings[team2]['played'] += 1
            
            # Update win/loss
            if winner == team1:
                standings[team1]['won'] += 1
                standings[team1]['points'] += 2
                standings[team2]['lost'] += 1
            else:
                standings[team2]['won'] += 1
                standings[team2]['points'] += 2
                standings[team1]['lost'] += 1
                
        # Sort by points, then NRR
        sorted_standings = sorted(
            standings.items(),
            key=lambda x: (x[1]['points'], x[1]['nrr']),
            reverse=True
        )
        
        return sorted_standings
    
    def display_league_table(self, standings: List[Tuple[str, Dict]]):
        """Display league standings in a formatted table."""
        print("\n" + "="*80)
        print(f"{'LEAGUE STANDINGS':^80}")
        print("="*80)
        
        print(f"{'TEAM':<20} {'P':<5} {'W':<5} {'L':<5} {'PTS':<5} {'NRR':<8}")
        print("-"*80)
        
        for team, stats in standings:
            print(f"{team:<20} {stats['played']:<5} {stats['won']:<5} {stats['lost']:<5} {stats['points']:<5} {stats['nrr']:<8.3f}")
        
        print("="*80)
    
    def display_match_scorecard(self, match_results: Dict):
        """Display match results in a nicely formatted cricket scorecard."""
        print("\n" + "="*80)
        print(f"{'MATCH SCORECARD':^80}")
        print("="*80)
        
        # Match result summary
        winner = match_results['result'].get('winner', 'Unknown')
        margin = match_results['result'].get('margin', 0)
        margin_type = match_results['result'].get('margin_type', 'runs')
        
        print(f"\nRESULT: {winner} won by {margin} {margin_type}")
        print("-"*80)
        
        # Display both innings
        for innings_num in [1, 2]:
            if innings_num not in match_results['innings']:
                continue
                
            innings = match_results['innings'][innings_num]
            batting_team = innings.get('batting_team', f"Team {innings_num}")
            score = innings.get('score', 0)
            wickets = innings.get('wickets', 0)
            overs = innings.get('overs', 20)
            
            # Format overs display
            overs_str = str(overs)
            if isinstance(overs, float):
                overs_int = int(overs)
                balls = int(round((overs - overs_int) * 6))
                overs_str = f"{overs_int}.{balls}"
            
            print(f"\n{batting_team} INNINGS: {score}/{wickets} ({overs_str} overs)")
            print("-"*80)
            
            # Display batsmen performances
            print(f"{'BATSMAN':<25} {'STATUS':<15} {'RUNS':<8} {'BALLS':<8} {'4s':<5} {'6s':<5} {'SR':<8}")
            print("-"*80)
            
            # Get batting performances
            batsmen = []
            if 'player_stats' in match_results and 'batting' in match_results['player_stats']:
                for player_id, stats in match_results['player_stats']['batting'].items():
                    if stats.get('innings') == innings_num:
                        batsmen.append({
                            'player_id': player_id,
                            'name': stats.get('name', player_id),
                            'runs': stats.get('runs', 0),
                            'balls': stats.get('balls', 0),
                            'fours': stats.get('fours', 0),
                            'sixes': stats.get('sixes', 0),
                            'dismissed': stats.get('dismissed', False),
                            'batting_position': stats.get('position', 999)
                        })
            
            if batsmen:
                batsmen.sort(key=lambda x: x.get('batting_position', 999))
                for batsman in batsmen:
                    name = batsman.get('name', batsman['player_id'])
                    status = "not out" if not batsman.get('dismissed', False) else "out"
                    runs = batsman.get('runs', 0)
                    balls = batsman.get('balls', 0)
                    fours = batsman.get('fours', 0)
                    sixes = batsman.get('sixes', 0)
                    sr = round((runs / balls * 100) if balls > 0 else 0, 2)
                    
                    print(f"{name:<25} {status:<15} {runs:<8} {balls:<8} {fours:<5} {sixes:<5} {sr:<8}")
            
            print("-"*80)
            
            # Display extras and total
            extras = innings.get('extras', 0)
            wides = innings.get('wides', 0)
            no_balls = innings.get('no_balls', 0) 
            byes = innings.get('byes', 0)
            leg_byes = innings.get('leg_byes', 0)
            print(f"Extras: {extras} (WD: {wides}, NB: {no_balls}, B: {byes}, LB: {leg_byes})")
            print(f"TOTAL: {score}/{wickets} in {overs_str} overs")
            print("-"*80)
            
            # Display bowling performances
            bowling_team = innings.get('bowling_team', '')
            if not bowling_team:
                team1 = match_results['teams'].get('team1', '')
                team2 = match_results['teams'].get('team2', '')
                bowling_team = team2 if batting_team == team1 else team1
                    
            print(f"\n{bowling_team} BOWLING:")
            print(f"{'BOWLER':<25} {'O':<5} {'M':<5} {'R':<5} {'W':<5} {'ECON':<8}")
            print("-"*80)
            
            # Get bowling performances
            bowlers = []
            if 'player_stats' in match_results and 'bowling' in match_results['player_stats']:
                for player_id, stats in match_results['player_stats']['bowling'].items():
                    if stats.get('innings') == innings_num:
                        bowlers.append({
                            'player_id': player_id,
                            'name': stats.get('name', player_id),
                            'overs': stats.get('overs', 0),
                            'balls': stats.get('balls', 0),
                            'runs': stats.get('runs', 0),
                            'wickets': stats.get('wickets', 0),
                            'maidens': stats.get('maidens', 0)
                        })
            
            if bowlers:
                bowlers.sort(key=lambda x: (x.get('overs', 0), x.get('balls', 0)), reverse=True)
                for bowler in bowlers:
                    name = bowler.get('name', bowler['player_id'])
                    overs = bowler.get('overs', 0)
                    balls = bowler.get('balls', 0)
                    
                    if isinstance(overs, float):
                        overs_int = int(overs)
                        balls_part = int(round((overs - overs_int) * 6))
                        overs_str = f"{overs_int}.{balls_part}"
                    else:
                        overs_str = f"{overs}.0"
                        
                    runs = bowler.get('runs', 0)
                    wickets = bowler.get('wickets', 0)
                    maidens = bowler.get('maidens', 0)
                    econ = round(runs / overs if overs > 0 else 0, 2)
                    
                    print(f"{name:<25} {overs_str:<5} {maidens:<5} {runs:<5} {wickets:<5} {econ:<8}")
            
            print("="*80)

# %%
# Create simulator instance
simulator = LeagueSimulator()
# Out:
# Loading data...
# Successfully loaded squad data from data\teams\squad_profiles.json
# Successfully loaded batting stats from data\players\batting_stats.json
# Successfully loaded bowling stats from data\players\bowling_stats.json
# Successfully loaded 49131 ball-by-ball records from data\matches\t20_bbb.csv
# Error processing ball-by-ball data: 'match_id'
# Arun Jaitley Stadium, Delhi
# Barsapara Cricket Stadium, Guwahati
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam
# Eden Gardens, Kolkata
# Himachal Pradesh Cricket Association Stadium, Dharamsala
# M Chinnaswamy Stadium, Bengaluru
# MA Chidambaram Stadium, Chepauk, Chennai
# Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur
# Narendra Modi Stadium, Ahmedabad
# Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh
# Rajiv Gandhi International Stadium, Uppal, Hyderabad
# Sawai Mansingh Stadium, Jaipur
# Wankhede Stadium, Mumbai
# Generated statistical profiles for 14 venues
# Successfully linked data for 10 teams and 228 players
# CSK {'name': 'Team CSK', 'players': ['28081', '1070665', '379140', '446763', '1292497', '425786', '230556', '1452455', '1131570', '959767', '26421', '477021', '662973', '1175428', '497121', '510530', '1070188', '269238', '234675', '714451', '942645', '1182529', '1125688', '826915', '344580', '1194795']}
# ['Urvil Patel', 'Jamie Overton', 'Dewald Brevis', 'Ayush Mhatre', 'Rachin Ravindra', 'Shivam Dube', 'Devon Conway', 'MS Dhoni', 'Vijay Shankar', 'Ravindra Jadeja', 'Sam Curran']
# Over 1 assigned to Khaleel Ahmed with score 8.042330629367036
# Over 2 assigned to Nathan Ellis with score 6.333333333333333
# Over 3 assigned to Noor Ahmad with score 2.588888888888889
# Over 4 assigned to Khaleel Ahmed with score 8.31011137803014
# Over 5 assigned to Nathan Ellis with score 13.047619047619047
# Over 6 assigned to Khaleel Ahmed with score 6.965868953787714
# Over 7 assigned to Nathan Ellis with score 15.68888888888889
# Over 8 assigned to Anshul Kamboj with score 15.25
# Over 9 assigned to Ravindra Jadeja with score 10.765409836065574
# Over 10 assigned to Ravichandran Ashwin with score 9.183085194375519
# Over 11 assigned to Nathan Ellis with score 16.78888888888889
# Over 12 assigned to Noor Ahmad with score 11.651428571428573
# Over 13 assigned to Shreyas Gopal with score 19.1
# Over 14 assigned to Noor Ahmad with score 13.529732645403378
# Over 15 assigned to Matheesha Pathirana with score 12.72357142857143
# Over 16 assigned to Ravichandran Ashwin with score 11.274285714285716
# Over 17 assigned to Noor Ahmad with score 16.25355855855856
# Over 18 assigned to Matheesha Pathirana with score 16.663688474178493
# Over 19 assigned to Sam Curran with score 12.394666666666666
# Over 20 assigned to Matheesha Pathirana with score 15.658577138146104
# Total bowling score: 242.21393423648396
# ['Urvil Patel', 'Khaleel Ahmed', 'Kamlesh Nagarkoti', 'Shreyas Gopal', 'Rachin Ravindra', 'Dewald Brevis', 'Ravichandran Ashwin', 'Taposh Ghosh', 'Devon Conway', 'Mukesh Choudhary', 'Noor Ahmad']
# ['Urvil Patel', 'Devon Conway', 'Dewald Brevis', 'Rachin Ravindra', 'Ravichandran Ashwin', 'Noor Ahmad', 'Khaleel Ahmed', 'Taposh Ghosh', 'Mukesh Choudhary', 'Shreyas Gopal', 'Kamlesh Nagarkoti']
# DC {'name': 'Team DC', 'players': ['422108', '1168049', '398439', '44828', '698315', '1277545', '595978', '554691', '1175489', '1131978', '1111917', '1449074', '1059570', '481046', '1292527', '1082752', '311592', '802575', '537119', '926851', '552152', '559235']}
# ['Jake Fraser-McGurk', 'KL Rahul', 'Karun Nair', 'Faf du Plessis', 'Axar Patel', 'Vipraj Nigam', 'Ashutosh Sharma', 'Tristan Stubbs', 'Abishek Porel', 'Sameer Rizvi', 'Darshan Nalkande']
# Over 1 assigned to Vipraj Nigam with score 7.795945945945946
# Over 2 assigned to Mukesh Kumar with score 8.986399262332874
# Over 3 assigned to Axar Patel with score 11.497142857142858
# Over 4 assigned to T Natarajan with score 10.55
# Over 5 assigned to Vipraj Nigam with score 15.895945945945947
# Over 6 assigned to Axar Patel with score 9.397142857142857
# Over 7 assigned to Mohit Sharma with score 15.950793650793651
# Over 8 assigned to Tristan Stubbs with score 19.4
# Over 9 assigned to Mohit Sharma with score 12.71079365079365
# Over 10 assigned to Dushmantha Chameera with score 17.166666666666664
# Over 11 assigned to Axar Patel with score 12.481062801932367
# Over 12 assigned to Mitchell Starc with score 19.220000000000002
# Over 13 assigned to Darshan Nalkande with score 16.623333333333335
# Over 14 assigned to Mukesh Kumar with score 15.796470588235294
# Over 15 assigned to Kuldeep Yadav with score 14.91563273935367
# Over 16 assigned to Mukesh Kumar with score 11.457899159663864
# Over 17 assigned to Mohit Sharma with score 12.882328939108602
# Over 18 assigned to Vipraj Nigam with score 18.8
# Over 19 assigned to Mitchell Starc with score 15.149160079686396
# Over 20 assigned to Darshan Nalkande with score 16.076363636363638
# Total bowling score: 282.75308211444155
# ['Jake Fraser-McGurk', 'Donovan Ferreira', 'Vipraj Nigam', 'Gaurav Tiwari', 'KL Rahul', 'Mitchell Starc', 'Tristan Stubbs', 'Mukesh Kumar', 'Darshan Nalkande', 'T Natarajan', 'Kuldeep Yadav']
# ['Jake Fraser-McGurk', 'KL Rahul', 'Darshan Nalkande', 'Mitchell Starc', 'Donovan Ferreira', 'Vipraj Nigam', 'Kuldeep Yadav', 'Tristan Stubbs', 'Mukesh Kumar', 'Gaurav Tiwari', 'T Natarajan']
# GT {'name': 'Team GT', 'players': ['1070173', '308967', '1207295', '1123073', '914541', '1292506', '853265', '719715', '1244751', '1048739', '447587', '793467', '1151288', '437316', '719719', '550215', '940973', '917159', '1175426', '596010', '1287033', '236779', '1083033', '423838', '793463']}
# ['Sai Sudharsan', 'Sai Kishore', 'M Shahrukh Khan', 'Shubman Gill', 'Rashid Khan', 'Sherfane Rutherford', 'Mahipal Lomror', 'Anuj Rawat', 'Jos Buttler', 'Rahul Tewatia', 'Arshad Khan']
# Over 1 assigned to Mohammed Siraj with score 11.663752808988765
# Over 2 assigned to Gerald Coetzee with score 11.435323383084576
# Over 3 assigned to Ishant Sharma with score 11.852093023255815
# Over 4 assigned to Sai Kishore with score 17.3
# Over 5 assigned to Ishant Sharma with score 16.092093023255813
# Over 6 assigned to Rashid Khan with score 13.04547619047619
# Over 7 assigned to Ishant Sharma with score 13.80952380952381
# Over 8 assigned to Washington Sundar with score 13.303333333333333
# Over 9 assigned to Mohammed Siraj with score 13.200000000000003
# Over 10 assigned to Gerald Coetzee with score 14.795454545454547
# Over 11 assigned to Sai Kishore with score 13.338095238095239
# Over 12 assigned to Prasidh Krishna with score 16.2875
# Over 13 assigned to Sai Kishore with score 14.953333333333333
# Over 14 assigned to Kagiso Rabada with score 11.617215189873418
# Over 15 assigned to Mahipal Lomror with score 16.400000000000002
# Over 16 assigned to Prasidh Krishna with score 20.14090909090909
# Over 17 assigned to Mohammed Siraj with score 14.725232426303855
# Over 18 assigned to Prasidh Krishna with score 14.870707070707072
# Over 19 assigned to Washington Sundar with score 17.73
# Over 20 assigned to Gerald Coetzee with score 19.06666666666667
# Total bowling score: 295.6267091332615
# ['Rahul Tewatia', 'Rashid Khan', 'Mahipal Lomror', 'M Shahrukh Khan', 'Jos Buttler', 'Sherfane Rutherford', 'Gerald Coetzee', 'Prasidh Krishna', 'Gurnoor Brar', 'Mohammed Siraj', 'Nishant Sindhu']
# ['Rahul Tewatia', 'Rashid Khan', 'M Shahrukh Khan', 'Mahipal Lomror', 'Mohammed Siraj', 'Sherfane Rutherford', 'Jos Buttler', 'Gerald Coetzee', 'Prasidh Krishna', 'Nishant Sindhu', 'Gurnoor Brar']
# ['Rahul Tewatia', 'Rashid Khan', 'Mahipal Lomror', 'M Shahrukh Khan', 'Jos Buttler', 'Sherfane Rutherford', 'Gerald Coetzee', 'Prasidh Krishna', 'Gurnoor Brar', 'Mohammed Siraj', 'Nishant Sindhu']
# KKR {'name': 'Team KKR', 'players': ['277916', '723105', '379143', '974087', '1292495', '820351', '290630', '1155253', '851403', '1079839', '8917', '1079470', '276298', '481979', '1209292', '1081442', '1123718', '1312645', '230558', '1108375', '1131754']}
# ['Mayank Markande', 'Angkrish Raghuvanshi', 'Venkatesh Iyer', 'Ramandeep Singh', 'Quinton de Kock', 'Sunil Narine', 'Rahmanullah Gurbaz', 'Ajinkya Rahane', 'Rinku Singh', 'Andre Russell', 'Rovman Powell']
# Over 1 assigned to Anukul Roy with score 12.700000000000001
# Over 2 assigned to Moeen Ali with score 16.051666666666666
# Over 3 assigned to Harshit Rana with score 12.126323529411765
# Over 4 assigned to Moeen Ali with score 19.901666666666667
# Over 5 assigned to Andre Russell with score 13.63816933638444
# Over 6 assigned to Moeen Ali with score 18.326666666666668
# Over 7 assigned to Anukul Roy with score 16.333333333333332
# Over 8 assigned to Varun Chakravarthy with score 16.347186352327924
# Over 9 assigned to Anukul Roy with score 17.383333333333333
# Over 10 assigned to Varun Chakravarthy with score 13.422186352327923
# Over 11 assigned to Andre Russell with score 14.757200694042801
# Over 12 assigned to Varun Chakravarthy with score 14.070263275404848
# Over 13 assigned to Sunil Narine with score 17.200802139037435
# Over 14 assigned to Moeen Ali with score 12.625000000000002
# Over 15 assigned to Vaibhav Arora with score 17.82
# Over 16 assigned to Anukul Roy with score 17.8
# Over 17 assigned to Vaibhav Arora with score 14.906515151515153
# Over 18 assigned to Sunil Narine with score 16.12
# Over 19 assigned to Spencer Johnson with score 15.708771929824563
# Over 20 assigned to Varun Chakravarthy with score 14.727358490566038
# Total bowling score: 311.96644391750954
# ['Rovman Powell', 'Quinton de Kock', 'Ramandeep Singh', 'Rahmanullah Gurbaz', 'Venkatesh Iyer', 'Varun Chakravarthy', 'Vaibhav Arora', 'Rinku Singh', 'Manish Pandey', 'Anukul Roy', 'Angkrish Raghuvanshi']
# ['Angkrish Raghuvanshi', 'Venkatesh Iyer', 'Quinton de Kock', 'Ramandeep Singh', 'Manish Pandey', 'Rinku Singh', 'Rahmanullah Gurbaz', 'Rovman Powell', 'Anukul Roy', 'Vaibhav Arora', 'Varun Chakravarthy']
# LSG {'name': 'Team LSG', 'players': ['931581', '321777', '600498', '1130300', '805235', '595267', '604302', '272450', '1175485', '1159711', '1339708', '1175429', '1403153', '1151270', '475281', '694211', '1176959', '1151286', '1460529', '1175458', '1356971', '1350768', '1292563', '1175441']}
# ['Mitchell Marsh', 'Nicholas Pooran', 'Avesh Khan', 'Akash Deep', 'Ayush Badoni', 'Shardul Thakur', 'David Miller', 'Rishabh Pant', 'Abdul Samad', 'Aiden Markram', 'Shahbaz Ahmed']
# Over 1 assigned to Akash Singh with score 10.922539682539686
# Over 2 assigned to Manimaran Siddharth with score 14.714285714285715
# Over 3 assigned to Mayank Yadav with score 11.1
# Over 4 assigned to Aiden Markram with score 9.15
# Over 5 assigned to Mitchell Marsh with score 17.0
# Over 6 assigned to Mayank Yadav with score 15.2
# Over 7 assigned to Digvesh Rathi with score 11.72982456140351
# Over 8 assigned to Mayank Yadav with score 15.157142857142858
# Over 9 assigned to Digvesh Rathi with score 14.17982456140351
# Over 10 assigned to Rajvardhan Hangargekar with score 17.3
# Over 11 assigned to Digvesh Rathi with score 14.029824561403508
# Over 12 assigned to Mayank Yadav with score 14.157142857142858
# Over 13 assigned to Avesh Khan with score 17.231060606060606
# Over 14 assigned to Ravi Bishnoi with score 13.12441082859493
# Over 15 assigned to Avesh Khan with score 11.356060606060606
# Over 16 assigned to Ravi Bishnoi with score 12.832450811211185
# Over 17 assigned to Shardul Thakur with score 14.342424242424244
# Over 18 assigned to Rajvardhan Hangargekar with score 16.700000000000003
# Over 19 assigned to Shardul Thakur with score 12.75909090909091
# Over 20 assigned to Mitchell Marsh with score 15.434408602150537
# Total bowling score: 278.4204914009146
# ['Matthew Breetzke', 'Nicholas Pooran', 'Mitchell Marsh', 'Abdul Samad', 'Shahbaz Ahmed', 'Avesh Khan', 'Shardul Thakur', 'Ravi Bishnoi', 'Akash Singh', 'Shamar Joseph', 'Mayank Yadav']
# ['Abdul Samad', 'Nicholas Pooran', 'Mitchell Marsh', 'Avesh Khan', 'Ravi Bishnoi', 'Shardul Thakur', 'Shahbaz Ahmed', 'Akash Singh', 'Matthew Breetzke', 'Mayank Yadav', 'Shamar Joseph']
# MI {'name': 'Team MI', 'players': ['34102', '446507', '1350762', '605661', '778241', '1410577', '1170265', '625371', '1287032', '897549', '502714', '1292502', '594322', '277912', '30288', '447261', '1209126', '461632', '1392201', '1148776', '1058214', '1122621', '625383']}
# ['Karn Sharma', 'Ryan Rickelton', 'Tilak Varma', 'Naman Dhir', 'Hardik Pandya', 'Will Jacks', 'Suryakumar Yadav', 'Rohit Sharma', 'Corbin Bosch', 'Deepak Chahar', 'Arjun Tendulkar']
# Over 1 assigned to Trent Boult with score 15.779573271996544
# Over 2 assigned to Jasprit Bumrah with score 14.289253110570652
# Over 3 assigned to Deepak Chahar with score 9.325714285714286
# Over 4 assigned to Trent Boult with score 17.345610910828302
# Over 5 assigned to Jasprit Bumrah with score 13.34231433506045
# Over 6 assigned to Deepak Chahar with score 5.735714285714287
# Over 7 assigned to Karn Sharma with score 13.382941176470588
# Over 8 assigned to Mitchell Santner with score 12.607554945054947
# Over 9 assigned to Reece Topley with score 14.700000000000003
# Over 10 assigned to Mitchell Santner with score 12.465054945054945
# Over 11 assigned to Ashwani Kumar with score 18.6
# Over 12 assigned to Jasprit Bumrah with score 17.200000000000003
# Over 13 assigned to Ashwani Kumar with score 13.969142857142858
# Over 14 assigned to Deepak Chahar with score 15.994285714285716
# Over 15 assigned to Hardik Pandya with score 14.51995798319328
# Over 16 assigned to Jasprit Bumrah with score 16.66554054054054
# Over 17 assigned to Trent Boult with score 15.60358139534884
# Over 18 assigned to Mitchell Santner with score 11.71
# Over 19 assigned to Corbin Bosch with score 20.8
# Over 20 assigned to Satyanarayana Raju with score 15.8
# Total bowling score: 289.8362397569763
# ['Naman Dhir', 'Mujeeb-ur-Rehman', 'Satyanarayana Raju', 'Will Jacks', 'Tilak Varma', 'Jasprit Bumrah', 'Suryakumar Yadav', 'Rohit Sharma', 'Ryan Rickelton', 'Mitchell Santner', 'Hardik Pandya']
# ['Rohit Sharma', 'Ryan Rickelton', 'Naman Dhir', 'Tilak Varma', 'Hardik Pandya', 'Will Jacks', 'Suryakumar Yadav', 'Mitchell Santner', 'Satyanarayana Raju', 'Jasprit Bumrah', 'Mujeeb-ur-Rehman']
# PBKS {'name': 'Team PBKS', 'players': ['642519', '1151273', '732293', '662235', '1364155', '1324449', '1161024', '377534', '325012', '1168641', '696401', '819429', '1175456', '1124283', '30102', '1339698', '1213979', '1125976', '430246', '777815', '1070196', '493773', '1163695', '1050545', '777515']}
# ['Josh Inglis', 'Lockie Ferguson', 'Nehal Wadhera', 'Priyansh Arya', 'Marcus Stoinis', 'Shreyas Iyer', 'Prabhsimran Singh', 'Shashank Singh', 'Azmatullah Omarzai', 'Harpreet Brar', 'Vijaykumar Vyshak']
# Over 1 assigned to Marcus Stoinis with score 12.313333333333334
# Over 2 assigned to Xavier Bartlett with score 9.700000000000001
# Over 3 assigned to Yuzvendra Chahal with score 9.333333333333334
# Over 4 assigned to Marco Jansen with score 10.85621423689093
# Over 5 assigned to Yash Thakur with score 12.506749672346004
# Over 6 assigned to Yuzvendra Chahal with score 19.583333333333336
# Over 7 assigned to Marcus Stoinis with score 9.69047619047619
# Over 8 assigned to Azmatullah Omarzai with score 16.228571428571428
# Over 9 assigned to Kuldeep Sen with score 19.85
# Over 10 assigned to Azmatullah Omarzai with score 17.37857142857143
# Over 11 assigned to Kuldeep Sen with score 18.46666666666667
# Over 12 assigned to Harpreet Brar with score 16.19676113360324
# Over 13 assigned to Vijaykumar Vyshak with score 14.524705882352942
# Over 14 assigned to Lockie Ferguson with score 15.195450980392158
# Over 15 assigned to Yash Thakur with score 12.763333333333335
# Over 16 assigned to Lockie Ferguson with score 14.894117647058824
# Over 17 assigned to Yuzvendra Chahal with score 15.579886406664144
# Over 18 assigned to Yash Thakur with score 14.22757151552039
# Over 19 assigned to Harpreet Brar with score 16.26126126126126
# Over 20 assigned to Yuzvendra Chahal with score 15.399886406664145
# Total bowling score: 290.95022419037315
# ['Yuzvendra Chahal', 'Vishnu Vinod', 'Nehal Wadhera', 'Lockie Ferguson', 'Prabhsimran Singh', 'Harpreet Brar', 'Pyla Avinash', 'Praveen Dubey', 'Marco Jansen', 'Shreyas Iyer', 'Priyansh Arya']
# ['Prabhsimran Singh', 'Lockie Ferguson', 'Nehal Wadhera', 'Priyansh Arya', 'Vishnu Vinod', 'Shreyas Iyer', 'Marco Jansen', 'Harpreet Brar', 'Praveen Dubey', 'Pyla Avinash', 'Yuzvendra Chahal']
# RR {'name': 'Team RR', 'players': ['425943', '1252585', '1408688', '1339031', '670025', '1151278', '1175488', '1079434', '604527', '1206052', '669855', '1138316', '784379', '1206039', '1159843', '822553', '974175', '1294342', '1131978', '438362']}
# ['Yashasvi Jaiswal', 'Kwena Maphaka', 'Vaibhav Suryavanshi', 'Shubham Dubey', 'Shimron Hetmyer', 'Riyan Parag', 'Nitish Rana', 'Sanju Samson', 'Ashutosh Sharma', 'Dhruv Jurel', 'Yudhvir Singh']
# Over 1 assigned to Yudhvir Singh with score 14.116666666666667
# Over 2 assigned to Akash Madhwal with score 16.934615384615384
# Over 3 assigned to Wanindu Hasaranga with score 17.63
# Over 4 assigned to Akash Madhwal with score 13.984615384615386
# Over 5 assigned to Wanindu Hasaranga with score 16.88
# Over 6 assigned to Sandeep Sharma with score 4.463014331946371
# Over 7 assigned to Akash Madhwal with score 15.284651162790698
# Over 8 assigned to Nitish Rana with score 12.940000000000001
# Over 9 assigned to Kumar Kartikeya with score 1.4954545454545451
# Over 10 assigned to Akash Madhwal with score 11.921210302575643
# Over 11 assigned to Maheesh Theekshana with score 7.006182795698926
# Over 12 assigned to Tushar Deshpande with score 10.322222222222223
# Over 13 assigned to Riyan Parag with score 18.450000000000003
# Over 14 assigned to Tushar Deshpande with score 12.716165413533835
# Over 15 assigned to Jofra Archer with score 16.777891156462584
# Over 16 assigned to Yudhvir Singh with score 11.633333333333333
# Over 17 assigned to Nitish Rana with score 17.54705882352941
# Over 18 assigned to Tushar Deshpande with score 12.478762331838563
# Over 19 assigned to Maheesh Theekshana with score 18.4010989010989
# Over 20 assigned to Tushar Deshpande with score 13.366454639530872
# Total bowling score: 264.34939739591334
# ['Ashutosh Sharma', 'Sandeep Sharma', 'Vaibhav Suryavanshi', 'Dhruv Jurel', 'Yudhvir Singh', 'Kumar Kartikeya', 'Yashasvi Jaiswal', 'Sanju Samson', 'Maheesh Theekshana', 'Riyan Parag', 'Akash Madhwal']
# ['Yashasvi Jaiswal', 'Dhruv Jurel', 'Vaibhav Suryavanshi', 'Ashutosh Sharma', 'Kumar Kartikeya', 'Riyan Parag', 'Yudhvir Singh', 'Sanju Samson', 'Sandeep Sharma', 'Akash Madhwal', 'Maheesh Theekshana']
# RCB {'name': 'Team RCB', 'players': ['823703', '253802', '669365', '721867', '1119026', '1167965', '403902', '471342', '232292', '892749', '677077', '1057399', '1194959', '288284', '822673', '1350792', '326016', '955235', '542023', '423842', '1349361', '1159720']}
# ['Jacob Bethell', 'Virat Kohli', 'Rajat Patidar', 'Romario Shepherd', 'Swapnil Singh', 'Phil Salt', 'Jitesh Sharma', 'Liam Livingstone', 'Tim David', 'Devdutt Padikkal', 'Krunal Pandya']
# Over 1 assigned to Josh Hazlewood with score 17.469444444444445
# Over 2 assigned to Suyash Sharma with score 9.066666666666666
# Over 3 assigned to Nuwan Thushara with score 11.15897435897436
# Over 4 assigned to Romario Shepherd with score 13.900000000000002
# Over 5 assigned to Suyash Sharma with score 17.316666666666666
# Over 6 assigned to Lungi Ngidi with score 12.5
# Over 7 assigned to Krunal Pandya with score 12.134149659863947
# Over 8 assigned to Josh Hazlewood with score 18.150000000000002
# Over 9 assigned to Liam Livingstone with score 15.412500000000001
# Over 10 assigned to Krunal Pandya with score 15.365816326530613
# Over 11 assigned to Josh Hazlewood with score 8.4
# Over 12 assigned to Liam Livingstone with score 10.912500000000001
# Over 13 assigned to Yash Dayal with score 16.036605211659285
# Over 14 assigned to Suyash Sharma with score 16.706666666666667
# Over 15 assigned to Yash Dayal with score 18.189236790606657
# Over 16 assigned to Josh Hazlewood with score 11.468468468468469
# Over 17 assigned to Lungi Ngidi with score 9.8
# Over 18 assigned to Yash Dayal with score 9.817899159663867
# Over 19 assigned to Romario Shepherd with score 2.500000000000001
# Over 20 assigned to Krunal Pandya with score 14.233333333333333
# Total bowling score: 260.53892775354507
# ['Phil Salt', 'Romario Shepherd', 'Jacob Bethell', 'Jitesh Sharma', 'Suyash Sharma', 'Anand Singh', 'Bhuvneshwar Kumar', 'Rajat Patidar', 'Liam Livingstone', 'Tim David', 'Lungi Ngidi']
# ['Tim David', 'Jacob Bethell', 'Romario Shepherd', 'Rajat Patidar', 'Jitesh Sharma', 'Phil Salt', 'Bhuvneshwar Kumar', 'Liam Livingstone', 'Anand Singh', 'Suyash Sharma', 'Lungi Ngidi']
# SRH {'name': 'Team SRH', 'players': ['720471', '1125958', '778963', '1409976', '432783', '1338607', '436757', '530011', '390481', '784373', '698189', '1216159', '1070183', '1175496', '489889', '481896', '1064812', '1159722', '942371', '390484', '1306214']}
# ['Travis Head', 'Abhishek Sharma', 'Pat Cummins', 'Heinrich Klaasen', 'Kamindu Mendis', 'Ishan Kishan', 'Aniket Verma', 'Nitish Kumar Reddy', 'Abhinav Manohar', 'Atharva Taide', 'Jaydev Unadkat']
# Over 1 assigned to Mohammed Shami with score 11.104039523324024
# Over 2 assigned to Simarjeet Singh with score 11.933333333333334
# Over 3 assigned to Mohammed Shami with score 10.237072635906808
# Over 4 assigned to Pat Cummins with score 12.060833333333335
# Over 5 assigned to Mohammed Shami with score 10.692209890808769
# Over 6 assigned to Harshal Patel with score 4.771978021978022
# Over 7 assigned to Simarjeet Singh with score 17.571428571428573
# Over 8 assigned to Rahul Chahar with score 10.796610169491526
# Over 9 assigned to Simarjeet Singh with score 16.071428571428573
# Over 10 assigned to Pat Cummins with score 13.110606060606063
# Over 11 assigned to Harsh Dubey with score 14.3
# Over 12 assigned to Eshan Malinga with score 13.05
# Over 13 assigned to Kamindu Mendis with score 20.0
# Over 14 assigned to Pat Cummins with score 15.622857142857143
# Over 15 assigned to Jaydev Unadkat with score 11.860952380952382
# Over 16 assigned to Rahul Chahar with score 13.356666666666666
# Over 17 assigned to Mohammed Shami with score 14.422802197802199
# Over 18 assigned to Eshan Malinga with score 19.233333333333334
# Over 19 assigned to Harshal Patel with score 13.892327403080191
# Over 20 assigned to Eshan Malinga with score 16.900000000000002
# Total bowling score: 270.988479236331
# ['Abhishek Sharma', 'Aniket Verma', 'Kamindu Mendis', 'Pat Cummins', 'Zeeshan Ansari', 'Sachin Baby', 'Heinrich Klaasen', 'Mohammed Shami', 'Nitish Kumar Reddy', 'Abhinav Manohar', 'Ishan Kishan']
# ['Abhishek Sharma', 'Heinrich Klaasen', 'Pat Cummins', 'Aniket Verma', 'Kamindu Mendis', 'Ishan Kishan', 'Nitish Kumar Reddy', 'Abhinav Manohar', 'Mohammed Shami', 'Zeeshan Ansari', 'Sachin Baby']
# Loaded data for 10 teams and 228 players

# %%
# Simulate the league
simulator.simulate_league()
# Out:
# Starting league simulation with 45 matches...
#
# Simulating match 1/45: CSK vs SRH
# ['1131570', '379140', '1070665', '959767', '26421', '1182529', '942645', '269238', '1125688', '344580', '1070188']
# 1 1
# ['1131570', '379140']
# 1 2
# ['1131570', '379140']
# 1 3
# ['1131570', '379140']
# 1 4
# ['1131570', '379140']
# 1 5
# ['1131570', '379140']
# 1 6
# ['379140', '1131570']
# 2 1
# ['379140', '1131570']
# 2 2
# ['379140', '1131570']
# 2 3
# ['379140', '1131570']
# 2 4
# ['379140', '1131570']
# 2 5
# ['1070665', '1131570']
# 2 6
# ['1070665', '1131570']
# 3 1
# ['1131570', '1070665']
# 3 2
# ['1131570', '1070665']
# 3 3
# ['1131570', '1070665']
# 3 4
# ['1131570', '1070665']
# 3 5
# ['1131570', '1070665']
# 3 6
# ['1131570', '1070665']
# 4 1
# ['1131570', '1070665']
# 4 2
# ['1131570', '1070665']
# 4 3
# ['1131570', '1070665']
# 4 4
# ['1131570', '1070665']
# 4 5
# ['1131570', '1070665']
# 4 6
# ['1131570', '1070665']
# 5 1
# ['1070665', '959767']
# 5 2
# ['1070665', '959767']
# 5 3
# ['959767', '1070665']
# 5 4
# ['959767', '1070665']
# 5 5
# ['959767', '1070665']
# 5 6
# ['1070665', '959767']
# 6 1
# ['1070665', '959767']
# 6 2
# ['1070665', '959767']
# 6 3
# ['1070665', '959767']
# 6 4
# ['1070665', '959767']
# 6 5
# ['1070665', '959767']
# 6 6
# ['1070665', '959767']
# 7 1
# ['1070665', '959767']
# 7 2
# ['959767', '1070665']
# 7 3
# ['959767', '1070665']
# 7 4
# ['1070665', '959767']
# 7 5
# ['959767', '1070665']
# 7 6
# ['959767', '1070665']
# 8 1
# ['1070665', '959767']
# 8 2
# ['959767', '1070665']
# 8 3
# ['959767', '1070665']
# 8 4
# ['959767', '1070665']
# 8 5
# ['959767', '1070665']
# 8 6
# ['959767', '1070665']
# 9 1
# ['1070665', '959767']
# 9 2
# ['1070665', '959767']
# 9 3
# ['1070665', '959767']
# 9 4
# ['1070665', '959767']
# 9 5
# ['1070665', '959767']
# 9 6
# ['959767', '1070665']
# 10 1
# ['1070665', '26421']
# 10 2
# ['1070665', '26421']
# 10 3
# ['26421', '1070665']
# 10 4
# ['1070665', '26421']
# 10 5
# ['26421', '1070665']
# 10 6
# ['26421', '1070665']
# 11 1
# ['1070665', '26421']
# 11 2
# ['26421', '1070665']
# 11 3
# ['26421', '1070665']
# 11 4
# ['26421', '1070665']
# 11 5
# ['26421', '1070665']
# 11 6
# ['1070665', '26421']
# 12 1
# ['1070665', '26421']
# 12 2
# ['26421', '1070665']
# 12 3
# ['26421', '1070665']
# 12 4
# ['1070665', '26421']
# 12 5
# ['26421', '1070665']
# 12 6
# ['1070665', '26421']
# 13 1
# ['26421', '1070665']
# 13 2
# ['26421', '1070665']
# 13 3
# ['26421', '1070665']
# 13 4
# ['26421', '1070665']
# 13 5
# ['1182529', '1070665']
# 13 6
# ['1182529', '1070665']
# 14 1
# ['1070665', '1182529']
# 14 2
# ['942645', '1182529']
# 14 3
# ['942645', '1182529']
# 14 4
# ['942645', '1182529']
# 14 5
# ['1182529', '942645']
# 14 6
# ['942645', '1182529']
# 15 1
# ['942645', '1182529']
# 15 2
# ['942645', '1182529']
# 15 3
# ['942645', '1182529']
# 15 4
# ['942645', '1182529']
# 15 5
# ['942645', '1182529']
# 15 6
# ['942645', '1182529']
# 16 1
# ['1182529', '942645']
# 16 2
# ['1182529', '942645']
# 16 3
# ['1182529', '942645']
# 16 4
# ['1182529', '942645']
# 16 5
# ['1182529', '942645']
# 16 6
# ['1182529', '942645']
# 17 1
# ['942645', '1182529']
# 17 2
# ['942645', '1182529']
# 17 3
# ['1182529', '942645']
# 17 4
# ['269238', '942645']
# 17 5
# ['269238', '942645']
# 17 6
# ['942645', '269238']
# 18 1
# ['269238', '942645']
# 18 2
# ['269238', '942645']
# 18 3
# ['942645', '269238']
# 18 4
# ['269238', '942645']
# 18 5
# ['942645', '269238']
# 18 6
# ['269238', '942645']
# 19 1
# ['942645', '1125688']
# 19 2
# ['942645', '1125688']
# 19 3
# ['1125688', '942645']
# 19 4
# ['1125688', '942645']
# 19 5
# ['942645', '1125688']
# 19 6
# ['942645', '1125688']
# 20 1
# ['1125688', '942645']
# 20 2
# ['1125688', '942645']
# 20 3
# ['942645', '1125688']
# 20 4
# ['942645', '1125688']
# 20 5
# ['344580', '1125688']
# 20 6
# ['344580', '1125688']
# ['1070183', '436757', '489889', '1409976', '784373', '720471', '1175496', '778963', '481896', '942371', '432783']
# 1 1
# ['1070183', '436757']
# 1 2
# ['1070183', '436757']
# 1 3
# ['1070183', '436757']
# 1 4
# ['1070183', '436757']
# 1 5
# ['1070183', '436757']
# 1 6
# ['436757', '1070183']
# 2 1
# ['1070183', '436757']
# 2 2
# ['1070183', '436757']
# 2 3
# ['1070183', '436757']
# 2 4
# ['1070183', '436757']
# 2 5
# ['436757', '1070183']
# 2 6
# ['436757', '1070183']
# 3 1
# ['1070183', '436757']
# 3 2
# ['436757', '1070183']
# 3 3
# ['436757', '1070183']
# 3 4
# ['436757', '1070183']
# 3 5
# ['436757', '1070183']
# 3 6
# ['1070183', '436757']
# 4 1
# ['1070183', '436757']
# 4 2
# ['1070183', '436757']
# 4 3
# ['436757', '1070183']
# 4 4
# ['1070183', '436757']
# 4 5
# ['436757', '1070183']
# 4 6
# ['436757', '1070183']
# 5 1
# ['436757', '1070183']
# 5 2
# ['1070183', '436757']
# 5 3
# ['1070183', '436757']
# 5 4
# ['1070183', '436757']
# 5 5
# ['436757', '1070183']
# 5 6
# ['1070183', '436757']
# 6 1
# ['436757', '1070183']
# 6 2
# ['436757', '1070183']
# 6 3
# ['1070183', '436757']
# 6 4
# ['1070183', '436757']
# 6 5
# ['436757', '1070183']
# 6 6
# ['436757', '1070183']
# 7 1
# ['1070183', '436757']
# 7 2
# ['436757', '1070183']
# 7 3
# ['1070183', '436757']
# 7 4
# ['436757', '1070183']
# 7 5
# ['1070183', '436757']
# 7 6
# ['1070183', '436757']
# 8 1
# ['436757', '1070183']
# 8 2
# ['1070183', '436757']
# 8 3
# ['1070183', '436757']
# 8 4
# ['1070183', '436757']
# 8 5
# ['1070183', '436757']
# 8 6
# ['1070183', '436757']
# 9 1
# ['1070183', '436757']
# 9 2
# ['1070183', '436757']
# 9 3
# ['436757', '1070183']
# 9 4
# ['436757', '1070183']
# 9 5
# ['436757', '1070183']
# 9 6
# ['1070183', '436757']
# 10 1
# ['1070183', '436757']
# 10 2
# ['1070183', '436757']
# 10 3
# ['1070183', '436757']
# 10 4
# ['436757', '1070183']
# 10 5
# ['1070183', '436757']
# 10 6
# ['1070183', '436757']
# 11 1
# ['1070183', '436757']
# 11 2
# ['436757', '1070183']
# 11 3
# ['436757', '1070183']
# 11 4
# ['1070183', '436757']
# 11 5
# ['436757', '1070183']
# 11 6
# ['436757', '1070183']
# 12 1
# ['1070183', '436757']
# 12 2
# ['1070183', '436757']
# 12 3
# ['1070183', '436757']
# 12 4
# ['436757', '1070183']
# 12 5
# ['1070183', '436757']
# 12 6
# ['436757', '1070183']
# 13 1
# ['436757', '1070183']
# 13 2
# ['436757', '1070183']
# 13 3
# ['1070183', '436757']
# 13 4
# ['1070183', '436757']
# 13 5
# ['1070183', '436757']
# 13 6
# ['436757', '1070183']
# 14 1
# ['1070183', '436757']
# 14 2
# ['436757', '1070183']
# 14 3
# ['1070183', '436757']
# 14 4
# ['1070183', '436757']
# 14 5
# ['436757', '1070183']
# 14 6
# ['436757', '1070183']
# 15 1
# ['1070183', '436757']
# 15 2
# ['1070183', '436757']
# 15 3
# ['1070183', '436757']
# 15 4
# ['436757', '1070183']
# 15 5
# ['436757', '1070183']
# 15 6
# ['436757', '1070183']
# 16 1
# ['1070183', '436757']
# 16 2
# ['436757', '1070183']
# 16 3
# ['1070183', '436757']
# 16 4
# ['436757', '1070183']
# 16 5
# ['1070183', '436757']
# 16 6
# ['436757', '1070183']
# 17 1
# ['436757', '1070183']
# 17 2
# ['436757', '1070183']
# 17 3
# ['1070183', '436757']
# 17 4
# ['1070183', '436757']
# 17 5
# ['436757', '1070183']
# 17 6
# ['1070183', '436757']
# 18 1
# ['1070183', '436757']
# 18 2
# ['1070183', '436757']
# 18 3
# ['436757', '1070183']
# 18 4
# ['1070183', '436757']
# 18 5
# ['1070183', '436757']
# 18 6
# ['1070183', '436757']
#
# ================================================================================
#                                 MATCH SCORECARD
# ================================================================================
#
# RESULT: Team SRH won by 10 wickets runs
# --------------------------------------------------------------------------------
#
# Team CSK INNINGS: 230/8 (19.4 overs)
# --------------------------------------------------------------------------------
# BATSMAN                   STATUS          RUNS     BALLS    4s    6s    SR
# --------------------------------------------------------------------------------
# Urvil Patel               out             50       17       0     6     294.12
# Devon Conway              out             9        5        1     0     180.0
# Dewald Brevis             out             45       28       3     2     160.71
# Rachin Ravindra           out             20       13       3     0     153.85
# Ravichandran Ashwin       out             18       13       0     1     138.46
# Noor Ahmad                out             19       10       2     1     190.0
# Khaleel Ahmed             out             48       20       5     3     240.0
# Taposh Ghosh              out             9        6        1     0     150.0
# Mukesh Choudhary          not out         4        4        0     0     100.0
# Shreyas Gopal             not out         6        2        0     1     300.0
# --------------------------------------------------------------------------------
# Extras: 0 (WD: 0, NB: 0, B: 0, LB: 0)
# TOTAL: 230/8 in 19.4 overs
# --------------------------------------------------------------------------------
#
# Team SRH BOWLING:
# BOWLER                    O     M     R     W     ECON
# --------------------------------------------------------------------------------
# Pat Cummins               4.0   0     62    2     15.5
# Mohammed Shami            3.0   0     43    1     14.33
# Ishan Kishan              3.0   0     39    1     13.0
# Nitish Kumar Reddy        3.0   0     31    2     10.33
# Zeeshan Ansari            2.0   0     20    0     10.0
# Kamindu Mendis            2.0   0     20    1     10.0
# Abhinav Manohar           1.0   0     13    1     13.0
# ================================================================================
#
# Team SRH INNINGS: 233/0 (17.4 overs)
# --------------------------------------------------------------------------------
# BATSMAN                   STATUS          RUNS     BALLS    4s    6s    SR
# --------------------------------------------------------------------------------
# Abhishek Sharma           not out         139      60       11    7     231.67
# Heinrich Klaasen          not out         86       44       4     3     195.45
# --------------------------------------------------------------------------------
# Extras: 0 (WD: 0, NB: 0, B: 0, LB: 0)
# TOTAL: 233/0 in 17.4 overs
# --------------------------------------------------------------------------------
#
# Team CSK BOWLING:
# BOWLER                    O     M     R     W     ECON
# --------------------------------------------------------------------------------
# Noor Ahmad                4.0   0     63    0     15.75
# Khaleel Ahmed             3.0   0     44    0     14.67
# Ravichandran Ashwin       3.0   0     38    0     12.67
# Shreyas Gopal             2.0   0     41    0     20.5
# Dewald Brevis             2.0   0     25    0     12.5
# Devon Conway              1.0   0     14    0     14.0
# ================================================================================
#
# Simulating match 2/45: GT vs MI
# ['423838', '793463', '719719', '853265', '940973', '914541', '308967', '596010', '917159', '1287033', '1292506']
# 1 1
# ['423838', '793463']
# 1 2
# ['423838', '793463']
# 1 3
# ['423838', '793463']
# 1 4
# ['719719', '793463']
# 1 5
# ['853265', '793463']
# 1 6
# ['853265', '793463']
# 2 1
# ['793463', '853265']
# 2 2
# ['793463', '853265']
# 2 3
# ['793463', '853265']
# 2 4
# ['793463', '853265']
# 2 5
# ['793463', '853265']
# 2 6
# ['853265', '793463']
# 3 1
# ['793463', '853265']
# 3 2
# ['793463', '853265']
# 3 3
# ['853265', '793463']
# 3 4
# ['793463', '853265']
# 3 5
# ['853265', '793463']
# 3 6
# ['853265', '793463']
# 4 1
# ['793463', '853265']
# 4 2
# ['793463', '853265']
# 4 3
# ['793463', '853265']
# 4 4
# ['793463', '853265']
# 4 5
# ['793463', '853265']
# 4 6
# ['853265', '793463']
# 5 1
# ['853265', '793463']
# 5 2
# ['853265', '793463']
# 5 3
# ['940973', '793463']
# 5 4
# ['793463', '940973']
# 5 5
# ['793463', '940973']
# 5 6
# ['793463', '940973']
# 6 1
# ['940973', '793463']
# 6 2
# ['940973', '793463']
# 6 3
# ['940973', '793463']
# 6 4
# ['940973', '793463']
# 6 5
# ['940973', '793463']
# 6 6
# ['940973', '793463']
# 7 1
# ['793463', '940973']
# 7 2
# ['940973', '793463']
# 7 3
# ['940973', '793463']
# 7 4
# ['940973', '793463']
# 7 5
# ['793463', '940973']
# 7 6
# ['793463', '940973']
# 8 1
# ['793463', '940973']
# 8 2
# ['940973', '793463']
# 8 3
# ['940973', '793463']
# 8 4
# ['793463', '940973']
# 8 5
# ['793463', '940973']
# 8 6
# ['940973', '793463']
# 9 1
# ['793463', '940973']
# 9 2
# ['793463', '940973']
# 9 3
# ['793463', '940973']
# 9 4
# ['940973', '793463']
# 9 5
# ['914541', '793463']
# 9 6
# ['793463', '914541']
# 10 1
# ['793463', '914541']
# 10 2
# ['793463', '914541']
# 10 3
# ['914541', '793463']
# 10 4
# ['793463', '914541']
# 10 5
# ['793463', '914541']
# 10 6
# ['914541', '793463']
# 11 1
# ['914541', '793463']
# 11 2
# ['914541', '793463']
# 11 3
# ['793463', '914541']
# 11 4
# ['793463', '914541']
# 11 5
# ['793463', '914541']
# 11 6
# ['914541', '793463']
# 12 1
# ['793463', '914541']
# 12 2
# ['914541', '793463']
# 12 3
# ['793463', '914541']
# 12 4
# ['793463', '914541']
# 12 5
# ['793463', '914541']
# 12 6
# ['793463', '914541']
# 13 1
# ['914541', '793463']
# 13 2
# ['914541', '793463']
# 13 3
# ['914541', '793463']
# 13 4
# ['914541', '793463']
# 13 5
# ['914541', '793463']
# 13 6
# ['308967', '793463']
# 14 1
# ['308967', '793463']
# 14 2
# ['308967', '793463']
# 14 3
# ['793463', '308967']
# 14 4
# ['308967', '793463']
# 14 5
# ['308967', '793463']
# 14 6
# ['596010', '793463']
# 15 1
# ['793463', '596010']
# 15 2
# ['793463', '596010']
# 15 3
# ['793463', '596010']
# 15 4
# ['596010', '793463']
# 15 5
# ['596010', '793463']
# 15 6
# ['793463', '596010']
# 16 1
# ['596010', '793463']
# 16 2
# ['596010', '793463']
# 16 3
# ['596010', '793463']
# 16 4
# ['596010', '793463']
# 16 5
# ['793463', '596010']
# 16 6
# ['793463', '596010']
# 17 1
# ['596010', '793463']
# 17 2
# ['596010', '793463']
# 17 3
# ['596010', '793463']
# 17 4
# ['596010', '793463']
# 17 5
# ['793463', '596010']
# 17 6
# ['596010', '793463']
# 18 1
# ['793463', '596010']
# 18 2
# ['596010', '793463']
# 18 3
# ['596010', '793463']
# 18 4
# ['596010', '793463']
# 18 5
# ['917159', '793463']
# 18 6
# ['917159', '793463']
# 19 1
# ['917159', '793463']
# 19 2
# ['793463', '917159']
# 19 3
# ['793463', '917159']
# 19 4
# ['917159', '793463']
# 19 5
# ['917159', '793463']
# 19 6
# ['793463', '917159']
# 20 1
# ['917159', '793463']
# 20 2
# ['917159', '793463']
# 20 3
# ['917159', '793463']
# 20 4
# ['917159', '793463']
# 20 5
# ['917159', '793463']
# 20 6
# ['793463', '917159']
# ['34102', '605661', '1287032', '1170265', '625371', '897549', '446507', '502714', '1392201', '625383', '1058214']
# 1 1
# ['34102', '605661']
# 1 2
# ['34102', '605661']
# 1 3
# ['34102', '605661']
# 1 4
# ['605661', '34102']
# 1 5
# ['605661', '34102']
# 1 6
# ['605661', '34102']
# 2 1
# ['34102', '605661']
# 2 2
# ['34102', '605661']
# 2 3
# ['34102', '605661']
# 2 4
# ['605661', '34102']
# 2 5
# ['34102', '605661']
# 2 6
# ['34102', '605661']
# 3 1
# ['605661', '34102']
# 3 2
# ['605661', '34102']
# 3 3
# ['605661', '34102']
# 3 4
# ['605661', '34102']
# 3 5
# ['605661', '34102']
# 3 6
# ['34102', '605661']
# 4 1
# ['605661', '34102']
# 4 2
# ['605661', '34102']
# 4 3
# ['34102', '605661']
# 4 4
# ['34102', '605661']
# 4 5
# ['34102', '605661']
# 4 6
# ['34102', '605661']
# 5 1
# ['605661', '34102']
# 5 2
# ['605661', '34102']
# 5 3
# ['34102', '605661']
# 5 4
# ['34102', '605661']
# 5 5
# ['605661', '34102']
# 5 6
# ['605661', '34102']
# 6 1
# ['34102', '605661']
# 6 2
# ['1287032', '605661']
# 6 3
# ['1287032', '605661']
# 6 4
# ['1287032', '605661']
# 6 5
# ['1170265', '605661']
# 6 6
# ['1170265', '605661']
# 7 1
# ['1170265', '605661']
# 7 2
# ['625371', '605661']
# 7 3
# ['625371', '605661']
# 7 4
# ['625371', '605661']
# 7 5
# ['605661', '625371']
# 7 6
# ['605661', '625371']
# 8 1
# ['625371', '897549']
# 8 2
# ['446507', '897549']
# 8 3
# ['897549', '446507']
# 8 4
# ['446507', '897549']
# 8 5
# ['446507', '897549']
# 8 6
# ['897549', '446507']
# 9 1
# ['446507', '897549']
# 9 2
# ['897549', '446507']
# 9 3
# ['446507', '897549']
# 9 4
# ['446507', '897549']
# 9 5
# ['897549', '446507']
# 9 6
# ['897549', '446507']
# 10 1
# ['446507', '897549']
# 10 2
# ['897549', '446507']
# 10 3
# ['446507', '897549']
# 10 4
# ['446507', '897549']
# 10 5
# ['502714', '897549']
# 10 6
# ['502714', '897549']
# 11 1
# ['502714', '897549']
# 11 2
# ['1392201', '897549']
# 11 3
# ['1392201', '897549']
# 11 4
# ['1392201', '897549']
# 11 5
# ['897549', '1392201']
# 11 6
# ['1392201', '897549']
# 12 1
# ['1392201', '897549']
# 12 2
# ['1392201', '897549']
# 12 3
# ['897549', '1392201']
# 12 4
# ['1392201', '897549']
# 12 5
# ['1392201', '897549']
# 12 6
# ['897549', '1392201']
# 13 1
# ['897549', '1392201']
# 13 2
# ['897549', '1392201']
# 13 3
# ['897549', '1392201']
# 13 4
# ['897549', '1392201']
# 13 5
# ['897549', '1392201']
# 13 6
# ['897549', '1392201']
# 14 1
# ['1392201', '897549']
# 14 2
# ['897549', '1392201']
# 14 3
# ['897549', '1392201']
# 14 4
# ['897549', '1392201']
# 14 5
# ['897549', '1392201']
# 14 6
# ['1392201', '897549']
# 15 1
# ['897549', '1392201']
# 15 2
# ['897549', '1392201']
# 15 3
# ['1392201', '897549']
# 15 4
# ['1392201', '897549']
# 15 5
# ['1392201', '897549']
# 15 6
# ['1392201', '897549']
# 16 1
# ['1392201', '897549']
# 16 2
# ['897549', '1392201']
# 16 3
# ['1392201', '897549']
# 16 4
# ['1392201', '897549']
# 16 5
# ['897549', '1392201']
# 16 6
# ['1392201', '897549']
# 17 1
# ['897549', '1392201']
# 17 2
# ['625383', '1392201']
# 17 3
# ['625383', '1392201']
# 17 4
# ['1392201', '625383']
# 17 5
# ['1392201', '625383']
# 17 6
# ['1058214', '625383']
# 18 1
# ['625383', '1058214']
# 18 2
# ['625383', '1058214']
# 18 3
# ['1058214', '625383']
# 18 4
# ['1058214', '625383']
# 18 5
# ['625383', '1058214']
# 18 6
# ['1058214', '625383']
# 19 1
# ['1058214', '625383']
# 19 2
# ['1058214', '625383']
# 19 3
# ['625383', '1058214']
# 19 4
# ['1058214', '625383']
# 19 5
# ['1058214', '625383']
# 19 6
# ['625383', '1058214']
# 20 1
# ['625383', '1058214']
# 20 2
# ['625383', '1058214']
# 20 3
# ['625383', '1058214']
# 20 4
# ['625383', '1058214']
# 20 5
# ['1058214', '625383']
# 20 6
# ['1058214', '625383']
#
# ================================================================================
#                                 MATCH SCORECARD
# ================================================================================
#
# RESULT: Team GT won by 33 runs runs
# --------------------------------------------------------------------------------
#
# Team GT INNINGS: 235/7 (19.1 overs)
# --------------------------------------------------------------------------------
# BATSMAN                   STATUS          RUNS     BALLS    4s    6s    SR
# --------------------------------------------------------------------------------
# Rahul Tewatia             out             8        3        2     0     266.67
# Rashid Khan               not out         113      51       7     5     221.57
# M Shahrukh Khan           out             0        1        0     0     0.0
# Mahipal Lomror            out             16       9        0     1     177.78
# Mohammed Siraj            out             15       13       1     0     115.38
# Sherfane Rutherford       out             19       12       2     0     158.33
# Jos Buttler               out             8        5        1     0     160.0
# Gerald Coetzee            out             21       12       1     1     175.0
# Prasidh Krishna           not out         18       9        2     1     200.0
# --------------------------------------------------------------------------------
# Extras: 0 (WD: 0, NB: 0, B: 0, LB: 0)
# TOTAL: 235/7 in 19.1 overs
# --------------------------------------------------------------------------------
#
# Team MI BOWLING:
# BOWLER                    O     M     R     W     ECON
# --------------------------------------------------------------------------------
# Jasprit Bumrah            4.0   0     60    1     15.0
# Will Jacks                3.0   0     43    3     14.33
# Hardik Pandya             3.0   0     40    1     13.33
# Rohit Sharma              2.0   0     18    1     9.0
# Mitchell Santner          2.0   0     27    0     13.5
# Satyanarayana Raju        1.0   0     15    1     15.0
# Naman Dhir                1.0   0     15    0     15.0
# ================================================================================
#
# Team MI INNINGS: 202/9 (19.5 overs)
# --------------------------------------------------------------------------------
# BATSMAN                   STATUS          RUNS     BALLS    4s    6s    SR
# --------------------------------------------------------------------------------
# Rohit Sharma              out             31       16       2     2     193.75
# Ryan Rickelton            out             30       17       2     1     176.47
# Naman Dhir                out             4        3        0     0     133.33
# Tilak Varma               out             5        3        1     0     166.67
# Hardik Pandya             out             7        4        1     0     175.0
# Will Jacks                out             56       24       4     4     233.33
# Suryakumar Yadav          out             17       9        1     1     188.89
# Mitchell Santner          out             1        3        0     0     33.33
# Satyanarayana Raju        out             18       19       2     0     94.74
# Jasprit Bumrah            not out         16       11       0     0     145.45
# Mujeeb-ur-Rehman          not out         16       10       2     0     160.0
# --------------------------------------------------------------------------------
# Extras: 0 (WD: 0, NB: 0, B: 0, LB: 0)
# TOTAL: 202/9 in 19.5 overs
# --------------------------------------------------------------------------------
#
# Team GT BOWLING:
# BOWLER                    O     M     R     W     ECON
# --------------------------------------------------------------------------------
# Mohammed Siraj            4.0   0     37    0     9.25
# Gerald Coetzee            4.0   0     38    3     9.5
# Prasidh Krishna           4.0   0     52    3     13.0
# Rashid Khan               3.0   0     32    3     10.67
# Jos Buttler               2.0   0     23    0     11.5
# Mahipal Lomror            1.0   0     8     0     8.0
# Sherfane Rutherford       1.0   0     11    0     11.0
# ================================================================================
#
# Simulating match 3/45: PBKS vs RCB
# ['892749', '1194959', '677077', '823703', '721867', '669365', '326016', '403902', '423842', '1350792', '542023']
# 1 1
# ['892749', '1194959']
# 1 2
# ['1194959', '892749']
# 1 3
# ['1194959', '892749']
# 1 4
# ['1194959', '892749']
# 1 5
# ['892749', '1194959']
# 1 6
# ['1194959', '892749']
# 2 1
# ['892749', '1194959']
# 2 2
# ['892749', '1194959']
# 2 3
# ['1194959', '892749']
# 2 4
# ['892749', '1194959']
# 2 5
# ['1194959', '892749']
# 2 6
# ['1194959', '892749']
# 3 1
# ['1194959', '892749']
# 3 2
# ['677077', '892749']
# 3 3
# ['677077', '892749']
# 3 4
# ['677077', '892749']
# 3 5
# ['823703', '892749']
# 3 6
# ['721867', '892749']
# 4 1
# ['721867', '892749']
# 4 2
# ['721867', '892749']
# 4 3
# ['892749', '721867']
# 4 4
# ['892749', '721867']
# 4 5
# ['892749', '721867']
# 4 6
# ['892749', '721867']
# 5 1
# ['892749', '721867']
# 5 2
# ['721867', '892749']
# 5 3
# ['669365', '892749']
# 5 4
# ['892749', '669365']
# 5 5
# ['892749', '669365']
# 5 6
# ['892749', '669365']
# 6 1
# ['892749', '669365']
# 6 2
# ['892749', '669365']
# 6 3
# ['892749', '669365']
# 6 4
# ['892749', '669365']
# 6 5
# ['669365', '892749']
# 6 6
# ['892749', '669365']
# 7 1
# ['669365', '892749']
# 7 2
# ['669365', '892749']
# 7 3
# ['892749', '669365']
# 7 4
# ['669365', '892749']
# 7 5
# ['669365', '892749']
# 7 6
# ['669365', '892749']
# 8 1
# ['669365', '892749']
# 8 2
# ['892749', '669365']
# 8 3
# ['669365', '892749']
# 8 4
# ['669365', '892749']
# 8 5
# ['669365', '892749']
# 8 6
# ['669365', '892749']
# 9 1
# ['892749', '669365']
# 9 2
# ['892749', '669365']
# 9 3
# ['892749', '669365']
# 9 4
# ['892749', '669365']
# 9 5
# ['892749', '669365']
# 9 6
# ['669365', '892749']
# 10 1
# ['892749', '669365']
# 10 2
# ['669365', '892749']
# 10 3
# ['669365', '892749']
# 10 4
# ['669365', '892749']
# 10 5
# ['892749', '669365']
# 10 6
# ['669365', '892749']
# 11 1
# ['892749', '669365']
# 11 2
# ['669365', '892749']
# 11 3
# ['892749', '669365']
# 11 4
# ['892749', '669365']
# 11 5
# ['669365', '892749']
# 11 6
# ['892749', '669365']
# 12 1
# ['669365', '892749']
# 12 2
# ['892749', '669365']
# 12 3
# ['892749', '669365']
# 12 4
# ['892749', '669365']
# 12 5
# ['892749', '669365']
# 12 6
# ['892749', '669365']
# 13 1
# ['892749', '669365']
# 13 2
# ['669365', '892749']
# 13 3
# ['669365', '892749']
# 13 4
# ['892749', '669365']
# 13 5
# ['669365', '892749']
# 13 6
# ['669365', '892749']
# 14 1
# ['892749', '669365']
# 14 2
# ['669365', '892749']
# 14 3
# ['669365', '892749']
# 14 4
# ['669365', '892749']
# 14 5
# ['892749', '669365']
# 14 6
# ['669365', '892749']
# 15 1
# ['892749', '669365']
# 15 2
# ['669365', '892749']
# 15 3
# ['669365', '892749']
# 15 4
# ['892749', '669365']
# 15 5
# ['892749', '669365']
# 15 6
# ['669365', '892749']
# 16 1
# ['669365', '892749']
# 16 2
# ['669365', '892749']
# 16 3
# ['892749', '669365']
# 16 4
# ['892749', '669365']
# 16 5
# ['892749', '669365']
# 16 6
# ['892749', '669365']
# 17 1
# ['669365', '892749']
# 17 2
# ['892749', '669365']
# 17 3
# ['669365', '892749']
# 17 4
# ['669365', '892749']
# 17 5
# ['892749', '669365']
# 17 6
# ['669365', '892749']
# 18 1
# ['892749', '669365']
# 18 2
# ['669365', '892749']
# 18 3
# ['669365', '892749']
# 18 4
# ['669365', '892749']
# 18 5
# ['669365', '892749']
# 18 6
# ['892749', '669365']
# 19 1
# ['669365', '892749']
# 19 2
# ['669365', '892749']
# 19 3
# ['669365', '892749']
# 19 4
# ['892749', '669365']
# 19 5
# ['892749', '669365']
# 19 6
# ['669365', '892749']
# 20 1
# ['669365', '892749']
# 20 2
# ['892749', '669365']
# 20 3
# ['669365', '892749']
# 20 4
# ['892749', '669365']
# 20 5
# ['669365', '892749']
# 20 6
# ['892749', '669365']
# ['1161024', '493773', '1151273', '1175456', '732293', '642519', '696401', '1168641', '777515', '1324449', '430246']
# 1 1
# ['1161024', '493773']
# 1 2
# ['1161024', '493773']
# 1 3
# ['493773', '1161024']
# 1 4
# ['493773', '1161024']
# 1 5
# ['493773', '1161024']
# 1 6
# ['1151273', '1161024']
# 2 1
# ['1161024', '1151273']
# 2 2
# ['1161024', '1151273']
# 2 3
# ['1161024', '1151273']
# 2 4
# ['1151273', '1161024']
# 2 5
# ['1151273', '1161024']
# 2 6
# ['1161024', '1151273']
# 3 1
# ['1151273', '1161024']
# 3 2
# ['1151273', '1161024']
# 3 3
# ['1161024', '1151273']
# 3 4
# ['1161024', '1151273']
# 3 5
# ['1161024', '1151273']
# 3 6
# ['1175456', '1151273']
# 4 1
# ['1175456', '1151273']
# 4 2
# ['1175456', '1151273']
# 4 3
# ['1151273', '1175456']
# 4 4
# ['1151273', '1175456']
# 4 5
# ['732293', '1175456']
# 4 6
# ['732293', '1175456']
# 5 1
# ['732293', '1175456']
# 5 2
# ['642519', '1175456']
# 5 3
# ['642519', '1175456']
# 5 4
# ['642519', '1175456']
# 5 5
# ['642519', '1175456']
# 5 6
# ['642519', '1175456']
# 6 1
# ['1175456', '642519']
# 6 2
# ['1175456', '642519']
# 6 3
# ['696401', '642519']
# 6 4
# ['696401', '642519']
# 6 5
# ['696401', '642519']
# 6 6
# ['696401', '642519']
# 7 1
# ['642519', '696401']
# 7 2
# ['642519', '696401']
# 7 3
# ['696401', '642519']
# 7 4
# ['696401', '642519']
# 7 5
# ['696401', '642519']
# 7 6
# ['696401', '642519']
# 8 1
# ['642519', '1168641']
# 8 2
# ['1168641', '642519']
# 8 3
# ['642519', '1168641']
# 8 4
# ['642519', '1168641']
# 8 5
# ['642519', '1168641']
# 8 6
# ['1168641', '642519']
# 9 1
# ['642519', '1168641']
# 9 2
# ['642519', '1168641']
# 9 3
# ['642519', '1168641']
# 9 4
# ['642519', '1168641']
# 9 5
# ['642519', '1168641']
# 9 6
# ['1168641', '642519']
# 10 1
# ['1168641', '642519']
# 10 2
# ['642519', '1168641']
# 10 3
# ['1168641', '642519']
# 10 4
# ['642519', '1168641']
# 10 5
# ['642519', '1168641']
# 10 6
# ['642519', '1168641']
# 11 1
# ['1168641', '642519']
# 11 2
# ['1168641', '642519']
# 11 3
# ['1168641', '642519']
# 11 4
# ['1168641', '642519']
# 11 5
# ['642519', '1168641']
# 11 6
# ['642519', '1168641']
# 12 1
# ['1168641', '642519']
# 12 2
# ['1168641', '642519']
# 12 3
# ['1168641', '642519']
# 12 4
# ['642519', '1168641']
# 12 5
# ['642519', '1168641']
# 12 6
# ['642519', '1168641']
# 13 1
# ['642519', '1168641']
# 13 2
# ['642519', '1168641']
# 13 3
# ['642519', '1168641']
# 13 4
# ['642519', '1168641']
# 13 5
# ['642519', '1168641']
# 13 6
# ['642519', '1168641']
# 14 1
# ['1168641', '642519']
# 14 2
# ['1168641', '642519']
# 14 3
# ['642519', '1168641']
# 14 4
# ['1168641', '642519']
# 14 5
# ['1168641', '642519']
# 14 6
# ['642519', '1168641']
# 15 1
# ['1168641', '642519']
# 15 2
# ['1168641', '642519']
# 15 3
# ['642519', '1168641']
# 15 4
# ['1168641', '642519']
# 15 5
# ['1168641', '642519']
# 15 6
# ['642519', '1168641']
# 16 1
# ['1168641', '642519']
# 16 2
# ['642519', '1168641']
# 16 3
# ['642519', '1168641']
# 16 4
# ['642519', '1168641']
# 16 5
# ['1168641', '642519']
# 16 6
# ['1168641', '642519']
# 17 1
# ['642519', '1168641']
# 17 2
# ['642519', '1168641']
# 17 3
# ['642519', '1168641']
# 17 4
# ['642519', '1168641']
# 17 5
# ['1168641', '642519']
# 17 6
# ['642519', '1168641']
# 18 1
# ['1168641', '642519']
# 18 2
# ['642519', '1168641']
# 18 3
# ['1168641', '642519']
# 18 4
# ['1168641', '642519']
# 18 5
# ['1168641', '642519']
# 18 6
# ['1168641', '642519']
# 19 1
# ['642519', '1168641']
# 19 2
# ['642519', '1168641']
# 19 3
# ['777515', '1168641']
# 19 4
# ['1168641', '777515']
# 19 5
# ['1324449', '777515']
# 19 6
# ['1324449', '777515']
# 20 1
# ['777515', '1324449']
# 20 2
# ['777515', '1324449']
# 20 3
# ['777515', '1324449']
# 20 4
# ['1324449', '777515']
# 20 5
# ['1324449', '777515']
# 20 6
# ['777515', '1324449']
#
# ================================================================================
#                                 MATCH SCORECARD
# ================================================================================
#
# RESULT: Team RCB won by 27 runs runs
# --------------------------------------------------------------------------------
#
# Team RCB INNINGS: 240/4 (19.5 overs)
# --------------------------------------------------------------------------------
# BATSMAN                   STATUS          RUNS     BALLS    4s    6s    SR
# --------------------------------------------------------------------------------
# Tim David                 not out         108      55       12    3     196.36
# Jacob Bethell             out             11       8        1     0     137.5
# Romario Shepherd          out             10       3        1     1     333.33
# Rajat Patidar             out             0        1        0     0     0.0
# Jitesh Sharma             out             6        4        0     0     150.0
# Phil Salt                 not out         102      47       7     5     217.02
# --------------------------------------------------------------------------------
# Extras: 0 (WD: 0, NB: 0, B: 0, LB: 0)
# TOTAL: 240/4 in 19.5 overs
# --------------------------------------------------------------------------------
#
# Team PBKS BOWLING:
# BOWLER                    O     M     R     W     ECON
# --------------------------------------------------------------------------------
# Yuzvendra Chahal          4.0   0     56    0     14.0
# Harpreet Brar             4.0   0     45    1     11.25
# Marco Jansen              3.0   0     43    0     14.33
# Lockie Ferguson           3.0   0     45    3     15.0
# Shreyas Iyer              2.0   0     23    0     11.5
# Nehal Wadhera             2.0   0     25    0     12.5
# ================================================================================
#
# Team PBKS INNINGS: 213/8 (19.5 overs)
# --------------------------------------------------------------------------------
# BATSMAN                   STATUS          RUNS     BALLS    4s    6s    SR
# --------------------------------------------------------------------------------
# Prabhsimran Singh         out             22       9        2     1     244.44
# Lockie Ferguson           out             4        3        0     0     133.33
# Nehal Wadhera             out             12       7        0     1     171.43
# Priyansh Arya             out             6        5        1     0     120.0
# Vishnu Vinod              out             1        3        0     0     33.33
# Shreyas Iyer              out             101      45       8     4     224.44
# Marco Jansen              out             18       8        2     1     225.0
# Harpreet Brar             out             31       28       0     0     110.71
# Praveen Dubey             not out         2        4        0     0     50.0
# Pyla Avinash              not out         9        4        0     1     225.0
# --------------------------------------------------------------------------------
# Extras: 0 (WD: 0, NB: 0, B: 0, LB: 0)
# TOTAL: 213/8 in 19.5 overs
# --------------------------------------------------------------------------------
#
# Team RCB BOWLING:
# BOWLER                    O     M     R     W     ECON
# --------------------------------------------------------------------------------
# Bhuvneshwar Kumar         4.0   0     39    3     9.75
# Suyash Sharma             4.0   0     57    1     14.25
# Liam Livingstone          4.0   0     43    0     10.75
# Rajat Patidar             3.0   0     20    0     6.67
# Romario Shepherd          2.0   0     27    3     13.5
# Lungi Ngidi               1.0   0     20    1     20.0
# ================================================================================
#
# Simulating match 4/45: GT vs SRH
# ['1070183', '436757', '489889', '1409976', '784373', '720471', '1175496', '778963', '481896', '942371', '432783']
# 1 1
# ['1070183', '436757']
# 1 2
# ['1070183', '436757']
# 1 3
# ['436757', '1070183']
# 1 4
# ['1070183', '436757']
# 1 5
# ['436757', '1070183']
# 1 6
# ['436757', '1070183']
# 2 1
# ['1070183', '436757']
# 2 2
# ['1070183', '436757']
# 2 3
# ['436757', '1070183']
# 2 4
# ['436757', '1070183']
# 2 5
# ['1070183', '436757']
# 2 6
# ['1070183', '436757']
# 3 1
# ['436757', '1070183']
# 3 2
# ['1070183', '436757']
# 3 3
# ['436757', '1070183']
# 3 4
# ['436757', '1070183']
# 3 5
# ['1070183', '436757']
# 3 6
# ['1070183', '436757']
# 4 1
# ['436757', '1070183']
# 4 2
# ['1070183', '436757']
# 4 3
# ['1070183', '436757']
# 4 4
# ['436757', '1070183']
# 4 5
# ['436757', '1070183']
# 4 6
# ['436757', '1070183']
# 5 1
# ['436757', '1070183']
# 5 2
# ['1070183', '436757']
# 5 3
# ['1070183', '436757']
# 5 4
# ['436757', '1070183']
# 5 5
# ['436757', '1070183']
# 5 6
# ['1070183', '436757']
# 6 1
# ['1070183', '436757']
# 6 2
# ['1070183', '436757']
# 6 3
# ['1070183', '436757']
# 6 4
# ['1070183', '436757']
# 6 5
# ['1070183', '436757']
# 6 6
# ['1070183', '436757']
# 7 1
# ['1070183', '436757']
# 7 2
# ['1070183', '436757']
# 7 3
# ['1070183', '436757']
# 7 4
# ['1070183', '436757']
# 7 5
# ['1070183', '436757']
# 7 6
# ['1070183', '436757']
# 8 1
# ['436757', '1070183']
# 8 2
# ['489889', '1070183']
# 8 3
# ['1070183', '489889']
# 8 4
# ['1070183', '489889']
# 8 5
# ['489889', '1070183']
# 8 6
# ['489889', '1070183']
# 9 1
# ['1070183', '489889']
# 9 2
# ['1070183', '489889']
# 9 3
# ['489889', '1070183']
# 9 4
# ['489889', '1070183']
# 9 5
# ['489889', '1070183']
# 9 6
# ['489889', '1070183']
# 10 1
# ['1070183', '489889']
# 10 2
# ['1070183', '489889']
# 10 3
# ['489889', '1070183']
# 10 4
# ['489889', '1070183']
# 10 5
# ['489889', '1070183']
# 10 6
# ['489889', '1070183']
# 11 1
# ['489889', '1070183']
# 11 2
# ['1070183', '489889']
# 11 3
# ['1070183', '489889']
# 11 4
# ['489889', '1070183']
# 11 5
# ['489889', '1070183']
# 11 6
# ['489889', '1070183']
# 12 1
# ['489889', '1070183']
# 12 2
# ['1070183', '489889']
# 12 3
# ['1070183', '489889']
# 12 4
# ['489889', '1070183']
# 12 5
# ['489889', '1070183']
# 12 6
# ['1070183', '489889']
# 13 1
# ['489889', '1070183']
# 13 2
# ['489889', '1070183']
# 13 3
# ['489889', '1070183']
# 13 4
# ['489889', '1070183']
# 13 5
# ['1070183', '489889']
# 13 6
# ['1409976', '489889']
# 14 1
# ['1409976', '489889']
# 14 2
# ['489889', '1409976']
# 14 3
# ['489889', '1409976']
# 14 4
# ['1409976', '489889']
# 14 5
# ['1409976', '489889']
# 14 6
# ['1409976', '489889']
# 15 1
# ['489889', '1409976']
# 15 2
# ['489889', '1409976']
# 15 3
# ['489889', '1409976']
# 15 4
# ['1409976', '489889']
# 15 5
# ['489889', '1409976']
# 15 6
# ['1409976', '489889']
# 16 1
# ['1409976', '489889']
# 16 2
# ['489889', '1409976']
# 16 3
# ['1409976', '489889']
# 16 4
# ['489889', '1409976']
# 16 5
# ['1409976', '489889']
# 16 6
# ['1409976', '489889']
# 17 1
# ['489889', '1409976']
# 17 2
# ['489889', '1409976']
# 17 3
# ['1409976', '489889']
# 17 4
# ['1409976', '489889']
# 17 5
# ['1409976', '489889']
# 17 6
# ['489889', '1409976']
# 18 1
# ['1409976', '489889']
# 18 2
# ['489889', '1409976']
# 18 3
# ['489889', '1409976']
# 18 4
# ['784373', '1409976']
# 18 5
# ['784373', '1409976']
# 18 6
# ['784373', '1409976']
# 19 1
# ['784373', '1409976']
# 19 2
# ['1409976', '784373']
# 19 3
# ['1409976', '784373']
# 19 4
# ['1409976', '784373']
# 19 5
# ['1409976', '784373']
# 19 6
# ['784373', '1409976']
# 20 1
# ['1409976', '784373']
# 20 2
# ['784373', '1409976']
# 20 3
# ['720471', '1409976']
# 20 4
# ['720471', '1409976']
# 20 5
# ['720471', '1409976']
# 20 6
# ['720471', '1409976']
# ['423838', '793463', '719719', '853265', '940973', '914541', '308967', '596010', '917159', '1287033', '1292506']
# 1 1
# ['423838', '793463']
# 1 2
# ['423838', '793463']
# 1 3
# ['423838', '793463']
# 1 4
# ['423838', '793463']
# 1 5
# ['423838', '793463']
# 1 6
# ['793463', '423838']
# 2 1
# ['793463', '423838']
# 2 2
# ['423838', '793463']
# 2 3
# ['793463', '423838']
# 2 4
# ['793463', '423838']
# 2 5
# ['423838', '793463']
# 2 6
# ['423838', '793463']
# 3 1
# ['793463', '423838']
# 3 2
# ['793463', '423838']
# 3 3
# ['793463', '423838']
# 3 4
# ['793463', '423838']
# 3 5
# ['793463', '423838']
# 3 6
# ['423838', '793463']
# 4 1
# ['423838', '793463']
# 4 2
# ['423838', '793463']
# 4 3
# ['793463', '423838']
# 4 4
# ['423838', '793463']
# 4 5
# ['793463', '423838']
# 4 6
# ['423838', '793463']
# 5 1
# ['423838', '793463']
# 5 2
# ['423838', '793463']
# 5 3
# ['423838', '793463']
# 5 4
# ['423838', '793463']
# 5 5
# ['423838', '793463']
# 5 6
# ['423838', '793463']
# 6 1
# ['423838', '793463']
# 6 2
# ['423838', '793463']
# 6 3
# ['793463', '423838']
# 6 4
# ['423838', '793463']
# 6 5
# ['793463', '423838']
# 6 6
# ['793463', '423838']
# 7 1
# ['793463', '423838']
# 7 2
# ['423838', '793463']
# 7 3
# ['423838', '793463']
# 7 4
# ['423838', '793463']
# 7 5
# ['793463', '423838']
# 7 6
# ['423838', '793463']
# 8 1
# ['793463', '423838']
# 8 2
# ['793463', '423838']
# 8 3
# ['793463', '423838']
# 8 4
# ['423838', '793463']
# 8 5
# ['423838', '793463']
# 8 6
# ['423838', '793463']
# 9 1
# ['423838', '793463']
# 9 2
# ['423838', '793463']
# 9 3
# ['793463', '423838']
# 9 4
# ['793463', '423838']
# 9 5
# ['793463', '423838']
# 9 6
# ['793463', '423838']
# 10 1
# ['423838', '793463']
# 10 2
# ['793463', '423838']
# 10 3
# ['793463', '423838']
# 10 4
# ['793463', '423838']
# 10 5
# ['423838', '793463']
# 10 6
# ['793463', '423838']
# 11 1
# ['423838', '793463']
# 11 2
# ['793463', '423838']
# 11 3
# ['423838', '793463']
# 11 4
# ['793463', '423838']
# 11 5
# ['793463', '423838']
# 11 6
# ['793463', '423838']
# 12 1
# ['793463', '423838']
# 12 2
# ['423838', '793463']
# 12 3
# ['423838', '793463']
# 12 4
# ['423838', '793463']
# 12 5
# ['423838', '793463']
# 12 6
# ['423838', '793463']
# 13 1
# ['793463', '423838']
# 13 2
# ['793463', '423838']
# 13 3
# ['793463', '423838']
# 13 4
# ['423838', '793463']
# 13 5
# ['793463', '423838']
# 13 6
# ['793463', '423838']
# 14 1
# ['423838', '793463']
# 14 2
# ['793463', '423838']
# 14 3
# ['793463', '423838']
# 14 4
# ['793463', '423838']
# 14 5
# ['423838', '793463']
# 14 6
# ['423838', '793463']
# 15 1
# ['423838', '793463']
# 15 2
# ['793463', '423838']
# 15 3
# ['793463', '423838']
# 15 4
# ['793463', '423838']
# 15 5
# ['423838', '793463']
# 15 6
# ['423838', '793463']
# 16 1
# ['793463', '423838']
# 16 2
# ['423838', '793463']
# 16 3
# ['793463', '423838']
# 16 4
# ['793463', '423838']
# 16 5
# ['423838', '793463']
# 16 6
# ['719719', '793463']
# 17 1
# ['793463', '719719']
# 17 2
# ['719719', '793463']
# 17 3
# ['793463', '719719']
#
# ================================================================================
#                                 MATCH SCORECARD
# ================================================================================
#
# RESULT: Team GT won by 9 wickets runs
# --------------------------------------------------------------------------------
#
# Team SRH INNINGS: 200/5 (19.4 overs)
# --------------------------------------------------------------------------------
# BATSMAN                   STATUS          RUNS     BALLS    4s    6s    SR
# --------------------------------------------------------------------------------
# Abhishek Sharma           out             71       38       7     2     186.84
# Heinrich Klaasen          out             22       16       3     0     137.5
# Pat Cummins               out             63       35       3     2     180.0
# Aniket Verma              not out         26       19       1     0     136.84
# Kamindu Mendis            out             8        6        0     0     133.33
# Ishan Kishan              out             6        4        1     0     150.0
# Nitish Kumar Reddy        not out         0        0        0     0     0
# --------------------------------------------------------------------------------
# Extras: 0 (WD: 0, NB: 0, B: 0, LB: 0)
# TOTAL: 200/5 in 19.4 overs
# --------------------------------------------------------------------------------
#
# Team GT BOWLING:
# BOWLER                    O     M     R     W     ECON
# --------------------------------------------------------------------------------
# Prasidh Krishna           4.0   0     51    1     12.75
# Rashid Khan               4.0   0     43    2     10.75
# Mohammed Siraj            3.0   0     42    0     14.0
# Gerald Coetzee            3.0   0     34    0     11.33
# Jos Buttler               2.0   0     11    0     5.5
# Mahipal Lomror            1.0   0     8     0     8.0
# Sherfane Rutherford       1.0   0     7     2     7.0
# ================================================================================
#
# Team GT INNINGS: 201/1 (9.1 overs)
# --------------------------------------------------------------------------------
# BATSMAN                   STATUS          RUNS     BALLS    4s    6s    SR
# --------------------------------------------------------------------------------
# Rahul Tewatia             out             101      47       9     5     214.89
# Rashid Khan               not out         86       46       7     2     186.96
# M Shahrukh Khan           not out         3        1        0     0     300.0
# --------------------------------------------------------------------------------
# Extras: 0 (WD: 0, NB: 0, B: 0, LB: 0)
# TOTAL: 201/1 in 9.1 overs
# --------------------------------------------------------------------------------
#
# Team SRH BOWLING:
# BOWLER                    O     M     R     W     ECON
# --------------------------------------------------------------------------------
# Mohammed Shami            4.0   0     56    0     14.0
# Pat Cummins               3.0   0     47    0     15.67
# Zeeshan Ansari            2.0   0     23    0     11.5
# Ishan Kishan              2.0   0     32    0     16.0
# Abhinav Manohar           1.0   0     9     0     9.0
# Kamindu Mendis            1.0   0     14    0     14.0
# Nitish Kumar Reddy        0.0   0     9     1     0
# ================================================================================
#
# Simulating match 5/45: LSG vs SRH
# ['1070183', '436757', '489889', '1409976', '784373', '720471', '1175496', '778963', '481896', '942371', '432783']
# 1 1
# ['1070183', '436757']
# 1 2
# ['1070183', '436757']
# 1 3
# ['1070183', '436757']
# 1 4
# ['1070183', '436757']
# 1 5
# ['1070183', '436757']
# 1 6
# ['1070183', '436757']
# 2 1
# ['436757', '1070183']
# 2 2
# ['436757', '1070183']
# 2 3
# ['436757', '1070183']
# 2 4
# ['436757', '1070183']
# 2 5
# ['436757', '1070183']
# 2 6
# ['436757', '1070183']
# 3 1
# ['1070183', '436757']
# 3 2
# ['1070183', '436757']
# 3 3
# ['1070183', '436757']
# 3 4
# ['1070183', '436757']
# 3 5
# ['1070183', '436757']
# 3 6
# ['1070183', '436757']
# 4 1
# ['436757', '1070183']
# 4 2
# ['1070183', '436757']
# 4 3
# ['436757', '1070183']
# 4 4
# ['1070183', '436757']
# 4 5
# ['1070183', '436757']
# 4 6
# ['1070183', '436757']
# 5 1
# ['1070183', '436757']
# 5 2
# ['1070183', '436757']
# 5 3
# ['1070183', '436757']
# 5 4
# ['1070183', '436757']
# 5 5
# ['1070183', '436757']
# 5 6
# ['436757', '1070183']
# 6 1
# ['436757', '1070183']
# 6 2
# ['436757', '1070183']
# 6 3
# ['436757', '1070183']
# 6 4
# ['436757', '1070183']
# 6 5
# ['1070183', '436757']
# 6 6
# ['489889', '436757']
# 7 1
# ['489889', '436757']
# 7 2
# ['489889', '436757']
# 7 3
# ['489889', '436757']
# 7 4
# ['489889', '436757']
# 7 5
# ['489889', '436757']
# 7 6
# ['436757', '489889']
# 8 1
# ['489889', '436757']
# 8 2
# ['489889', '436757']
# 8 3
# ['489889', '436757']
# 8 4
# ['489889', '436757']
# 8 5
# ['489889', '436757']
# 8 6
# ['436757', '489889']
# 9 1
# ['436757', '489889']
# 9 2
# ['436757', '489889']
# 9 3
# ['489889', '436757']
# 9 4
# ['436757', '489889']
# 9 5
# ['489889', '436757']
# 9 6
# ['489889', '436757']
# 10 1
# ['436757', '489889']
# 10 2
# ['436757', '489889']
# 10 3
# ['489889', '436757']
# 10 4
# ['489889', '436757']
# 10 5
# ['436757', '489889']
# 10 6
# ['489889', '436757']
# 11 1
# ['436757', '489889']
# 11 2
# ['436757', '489889']
# 11 3
# ['436757', '489889']
# 11 4
# ['436757', '489889']
# 11 5
# ['436757', '489889']
# 11 6
# ['436757', '489889']
# 12 1
# ['489889', '436757']
# 12 2
# ['489889', '436757']
# 12 3
# ['489889', '436757']
# 12 4
# ['436757', '489889']
# 12 5
# ['436757', '489889']
# 12 6
# ['436757', '489889']
# 13 1
# ['436757', '489889']
# 13 2
# ['489889', '436757']
# 13 3
# ['489889', '436757']
# 13 4
# ['436757', '489889']
# 13 5
# ['489889', '436757']
# 13 6
# ['489889', '436757']
# 14 1
# ['489889', '436757']
# 14 2
# ['436757', '489889']
# 14 3
# ['436757', '489889']
# 14 4
# ['436757', '489889']
# 14 5
# ['436757', '489889']
# 14 6
# ['436757', '489889']
# 15 1
# ['489889', '436757']
# 15 2
# ['489889', '436757']
# 15 3
# ['489889', '436757']
# 15 4
# ['489889', '436757']
# 15 5
# ['436757', '489889']
# 15 6
# ['436757', '489889']
# 16 1
# ['489889', '436757']
# 16 2
# ['436757', '489889']
# 16 3
# ['489889', '436757']
# 16 4
# ['489889', '436757']
# 16 5
# ['489889', '436757']
# 16 6
# ['489889', '436757']
# 17 1
# ['436757', '489889']
# 17 2
# ['436757', '489889']
# 17 3
# ['489889', '436757']
# 17 4
# ['489889', '436757']
# 17 5
# ['489889', '436757']
# 17 6
# ['436757', '489889']
# 18 1
# ['436757', '489889']
# 18 2
# ['489889', '436757']
# 18 3
# ['436757', '489889']
# 18 4
# ['436757', '489889']
# 18 5
# ['436757', '489889']
# 18 6
# ['436757', '489889']
# 19 1
# ['489889', '436757']
# 19 2
# ['436757', '489889']
# 19 3
# ['436757', '489889']
# 19 4
# ['489889', '436757']
# 19 5
# ['436757', '489889']
# 19 6
# ['436757', '489889']
# 20 1
# ['489889', '436757']
# 20 2
# ['1409976', '436757']
# 20 3
# ['784373', '436757']
# 20 4
# ['784373', '436757']
# 20 5
# ['784373', '436757']
# 20 6
# ['436757', '784373']
# ['1175485', '604302', '272450', '694211', '1175441', '475281', '1159711', '1175458', '595267', '1292563', '1356971']
# 1 1
# ['1175485', '604302']
# 1 2
# ['604302', '1175485']
# 1 3
# ['272450', '1175485']
# 1 4
# ['272450', '1175485']
# 1 5
# ['272450', '1175485']
# 1 6
# ['272450', '1175485']
# 2 1
# ['1175485', '272450']
# 2 2
# ['1175485', '272450']
# 2 3
# ['1175485', '272450']
# 2 4
# ['1175485', '272450']
# 2 5
# ['272450', '1175485']
# 2 6
# ['272450', '1175485']
# 3 1
# ['272450', '1175485']
# 3 2
# ['272450', '1175485']
# 3 3
# ['272450', '1175485']
# 3 4
# ['272450', '1175485']
# 3 5
# ['272450', '1175485']
# 3 6
# ['272450', '1175485']
# 4 1
# ['272450', '1175485']
# 4 2
# ['1175485', '272450']
# 4 3
# ['272450', '1175485']
# 4 4
# ['1175485', '272450']
# 4 5
# ['272450', '1175485']
# 4 6
# ['1175485', '272450']
# 5 1
# ['272450', '1175485']
# 5 2
# ['1175485', '272450']
# 5 3
# ['272450', '1175485']
# 5 4
# ['272450', '1175485']
# 5 5
# ['272450', '1175485']
# 5 6
# ['272450', '1175485']
# 6 1
# ['272450', '1175485']
# 6 2
# ['272450', '1175485']
# 6 3
# ['1175485', '272450']
# 6 4
# ['272450', '1175485']
# 6 5
# ['272450', '1175485']
# 6 6
# ['272450', '1175485']
# 7 1
# ['1175485', '272450']
# 7 2
# ['272450', '1175485']
# 7 3
# ['1175485', '272450']
# 7 4
# ['272450', '1175485']
# 7 5
# ['1175485', '272450']
# 7 6
# ['1175485', '272450']
# 8 1
# ['1175485', '272450']
# 8 2
# ['1175485', '272450']
# 8 3
# ['1175485', '272450']
# 8 4
# ['1175485', '272450']
# 8 5
# ['272450', '1175485']
# 8 6
# ['272450', '1175485']
# 9 1
# ['1175485', '272450']
# 9 2
# ['1175485', '272450']
# 9 3
# ['1175485', '272450']
# 9 4
# ['1175485', '272450']
# 9 5
# ['1175485', '272450']
# 9 6
# ['1175485', '272450']
# 10 1
# ['272450', '1175485']
# 10 2
# ['272450', '1175485']
# 10 3
# ['1175485', '272450']
# 10 4
# ['272450', '1175485']
# 10 5
# ['1175485', '272450']
# 10 6
# ['1175485', '272450']
# 11 1
# ['272450', '1175485']
# 11 2
# ['272450', '1175485']
# 11 3
# ['1175485', '272450']
# 11 4
# ['272450', '1175485']
# 11 5
# ['272450', '1175485']
# 11 6
# ['1175485', '272450']
# 12 1
# ['1175485', '272450']
# 12 2
# ['272450', '1175485']
# 12 3
# ['272450', '1175485']
# 12 4
# ['272450', '1175485']
# 12 5
# ['272450', '1175485']
# 12 6
# ['1175485', '272450']
# 13 1
# ['272450', '1175485']
# 13 2
# ['1175485', '272450']
# 13 3
# ['1175485', '272450']
# 13 4
# ['272450', '1175485']
# 13 5
# ['1175485', '272450']
# 13 6
# ['1175485', '272450']
# 14 1
# ['272450', '1175485']
# 14 2
# ['272450', '1175485']
# 14 3
# ['1175485', '272450']
# 14 4
# ['272450', '1175485']
# 14 5
# ['1175485', '272450']
# 14 6
# ['1175485', '272450']
# 15 1
# ['1175485', '272450']
# 15 2
# ['1175485', '272450']
# 15 3
# ['272450', '1175485']
# 15 4
# ['1175485', '272450']
# 15 5
# ['272450', '1175485']
# 15 6
# ['272450', '1175485']
# 16 1
# ['1175485', '272450']
# 16 2
# ['1175485', '272450']
# 16 3
# ['272450', '1175485']
# 16 4
# ['272450', '1175485']
# 16 5
# ['272450', '1175485']
# 16 6
# ['1175485', '272450']
# 17 1
# ['1175485', '272450']
# 17 2
# ['272450', '1175485']
# 17 3
# ['272450', '1175485']
# 17 4
# ['272450', '1175485']
# 17 5
# ['272450', '1175485']
# 17 6
# ['1175485', '272450']
# 18 1
# ['1175485', '272450']
# 18 2
# ['1175485', '272450']
# 18 3
# ['694211', '272450']
# 18 4
# ['694211', '272450']
# 18 5
# ['694211', '272450']
# 18 6
# ['694211', '272450']
# 19 1
# ['694211', '272450']
# 19 2
# ['694211', '272450']
# 19 3
# ['694211', '272450']
# 19 4
# ['694211', '272450']
# 19 5
# ['694211', '272450']
# 19 6
# ['694211', '272450']
# 20 1
# ['694211', '272450']
# 20 2
# ['1175441', '272450']
# 20 3
# ['475281', '272450']
# 20 4
# ['475281', '272450']
# 20 5
# ['1159711', '272450']
# 20 6
# ['1159711', '272450']
#
# ================================================================================
#                                 MATCH SCORECARD
# ================================================================================
#
# RESULT: Team SRH won by 31 runs runs
# --------------------------------------------------------------------------------
#
# Team SRH INNINGS: 255/3 (19.3 overs)
# --------------------------------------------------------------------------------
# BATSMAN                   STATUS          RUNS     BALLS    4s    6s    SR
# --------------------------------------------------------------------------------
# Abhishek Sharma           out             43       21       4     1     204.76
# Heinrich Klaasen          not out         109      52       14    2     209.62
# Pat Cummins               out             87       38       2     5     228.95
# ...
# Shahbaz Ahmed             1.0   0     18    0     18.0
# Matthew Breetzke          1.0   0     14    0     14.0
# Shardul Thakur            1.0   0     12    0     12.0
# ================================================================================
#
# Simulating match 45/45: KKR vs LSG
# ['1175485', '604302', '272450', '694211', '1175441', '475281', '1159711', '1175458', '595267', '1292563', '1356971']
# 1 1
# ['1175485', '604302']
# 1 2
# ['1175485', '604302']
# 1 3
# ['604302', '1175485']
# 1 4
# ['604302', '1175485']
# 1 5
# ['604302', '1175485']
# 1 6
# ['1175485', '604302']
# 2 1
# ['604302', '1175485']
# 2 2
# ['1175485', '604302']
# 2 3
# ['1175485', '604302']
# 2 4
# ['604302', '1175485']
# 2 5
# ['1175485', '604302']
# 2 6
# ['1175485', '604302']
# 3 1
# ['1175485', '604302']
# 3 2
# ['1175485', '604302']
# 3 3
# ['604302', '1175485']
# 3 4
# ['604302', '1175485']
# 3 5
# ['604302', '1175485']
# 3 6
# ['604302', '1175485']
# 4 1
# ['1175485', '604302']
# 4 2
# ['604302', '1175485']
# 4 3
# ['604302', '1175485']
# 4 4
# ['604302', '1175485']
# 4 5
# ['272450', '1175485']
# 4 6
# ['272450', '1175485']
# 5 1
# ['1175485', '272450']
# 5 2
# ['272450', '1175485']
# 5 3
# ['1175485', '272450']
# 5 4
# ['272450', '1175485']
# 5 5
# ['1175485', '272450']
# 5 6
# ['272450', '1175485']
# 6 1
# ['1175485', '272450']
# 6 2
# ['272450', '1175485']
# 6 3
# ['272450', '1175485']
# 6 4
# ['1175485', '272450']
# 6 5
# ['1175485', '272450']
# 6 6
# ['1175485', '272450']
# 7 1
# ['272450', '1175485']
# 7 2
# ['272450', '1175485']
# 7 3
# ['272450', '1175485']
# 7 4
# ['272450', '1175485']
# 7 5
# ['272450', '1175485']
# 7 6
# ['1175485', '272450']
# 8 1
# ['272450', '1175485']
# 8 2
# ['272450', '1175485']
# 8 3
# ['1175485', '272450']
# 8 4
# ['272450', '1175485']
# 8 5
# ['272450', '1175485']
# 8 6
# ['1175485', '272450']
# 9 1
# ['1175485', '272450']
# 9 2
# ['1175485', '272450']
# 9 3
# ['1175485', '272450']
# 9 4
# ['1175485', '272450']
# 9 5
# ['1175485', '272450']
# 9 6
# ['1175485', '272450']
# 10 1
# ['1175485', '272450']
# 10 2
# ['1175485', '272450']
# 10 3
# ['272450', '1175485']
# 10 4
# ['1175485', '272450']
# 10 5
# ['272450', '1175485']
# 10 6
# ['1175485', '272450']
# 11 1
# ['1175485', '272450']
# 11 2
# ['1175485', '272450']
# 11 3
# ['272450', '1175485']
# 11 4
# ['272450', '1175485']
# 11 5
# ['1175485', '272450']
# 11 6
# ['272450', '1175485']
# 12 1
# ['1175485', '272450']
# 12 2
# ['1175485', '272450']
# 12 3
# ['1175485', '272450']
# 12 4
# ['272450', '1175485']
# 12 5
# ['272450', '1175485']
# 12 6
# ['1175485', '272450']
# 13 1
# ['1175485', '272450']
# 13 2
# ['272450', '1175485']
# 13 3
# ['272450', '1175485']
# 13 4
# ['272450', '1175485']
# 13 5
# ['272450', '1175485']
# 13 6
# ['272450', '1175485']
# 14 1
# ['272450', '1175485']
# 14 2
# ['1175485', '272450']
# 14 3
# ['1175485', '272450']
# 14 4
# ['272450', '1175485']
# 14 5
# ['1175485', '272450']
# 14 6
# ['272450', '1175485']
# 15 1
# ['1175485', '272450']
# 15 2
# ['1175485', '272450']
# 15 3
# ['272450', '1175485']
# 15 4
# ['272450', '1175485']
# 15 5
# ['1175485', '272450']
# 15 6
# ['272450', '1175485']
# 16 1
# ['1175485', '272450']
# 16 2
# ['1175485', '272450']
# 16 3
# ['272450', '1175485']
# 16 4
# ['272450', '1175485']
# 16 5
# ['272450', '1175485']
# 16 6
# ['272450', '1175485']
# 17 1
# ['1175485', '694211']
# 17 2
# ['1175485', '694211']
# 17 3
# ['1175485', '694211']
# 17 4
# ['1175485', '694211']
# 17 5
# ['1175485', '694211']
# 17 6
# ['1175485', '694211']
# 18 1
# ['694211', '1175485']
# 18 2
# ['694211', '1175485']
# 18 3
# ['1175485', '694211']
# 18 4
# ['1175485', '694211']
# 18 5
# ['1175485', '694211']
# 18 6
# ['1175485', '694211']
# 19 1
# ['694211', '1175485']
# 19 2
# ['694211', '1175485']
# 19 3
# ['1175485', '694211']
# 19 4
# ['694211', '1175485']
# 19 5
# ['694211', '1175485']
# 19 6
# ['694211', '1175485']
# 20 1
# ['1175485', '694211']
# 20 2
# ['694211', '1175485']
# 20 3
# ['694211', '1175485']
# 20 4
# ['694211', '1175485']
# 20 5
# ['694211', '1175485']
# 20 6
# ['694211', '1175485']
# ['1292495', '851403', '379143', '1079470', '290630', '723105', '974087', '820351', '1079839', '1209292', '1108375']
# 1 1
# ['1292495', '851403']
# 1 2
# ['1292495', '851403']
# 1 3
# ['1292495', '851403']
# 1 4
# ['1292495', '851403']
# 1 5
# ['1292495', '851403']
# 1 6
# ['851403', '1292495']
# 2 1
# ['851403', '1292495']
# 2 2
# ['851403', '1292495']
# 2 3
# ['851403', '1292495']
# 2 4
# ['851403', '1292495']
# 2 5
# ['1292495', '851403']
# 2 6
# ['1292495', '851403']
# 3 1
# ['1292495', '851403']
# 3 2
# ['1292495', '851403']
# 3 3
# ['1292495', '851403']
# 3 4
# ['1292495', '851403']
# 3 5
# ['1292495', '851403']
# 3 6
# ['851403', '1292495']
# 4 1
# ['1292495', '851403']
# 4 2
# ['1292495', '851403']
# 4 3
# ['851403', '1292495']
# 4 4
# ['851403', '1292495']
# 4 5
# ['1292495', '851403']
# 4 6
# ['851403', '1292495']
# 5 1
# ['1292495', '851403']
# 5 2
# ['1292495', '851403']
# 5 3
# ['1292495', '851403']
# 5 4
# ['1292495', '851403']
# 5 5
# ['1292495', '851403']
# 5 6
# ['1292495', '851403']
# 6 1
# ['851403', '379143']
# 6 2
# ['379143', '851403']
# 6 3
# ['379143', '851403']
# 6 4
# ['379143', '851403']
# 6 5
# ['1079470', '851403']
# 6 6
# ['1079470', '851403']
# 7 1
# ['851403', '1079470']
# 7 2
# ['851403', '1079470']
# 7 3
# ['851403', '1079470']
# 7 4
# ['1079470', '851403']
# 7 5
# ['851403', '1079470']
# 7 6
# ['851403', '1079470']
# 8 1
# ['1079470', '851403']
# 8 2
# ['851403', '1079470']
# 8 3
# ['1079470', '851403']
# 8 4
# ['1079470', '851403']
# 8 5
# ['851403', '1079470']
# 8 6
# ['851403', '1079470']
# 9 1
# ['851403', '1079470']
# 9 2
# ['1079470', '851403']
# 9 3
# ['851403', '1079470']
# 9 4
# ['851403', '1079470']
# 9 5
# ['851403', '1079470']
# 9 6
# ['1079470', '851403']
# 10 1
# ['851403', '1079470']
# 10 2
# ['1079470', '851403']
# 10 3
# ['851403', '1079470']
# 10 4
# ['1079470', '851403']
# 10 5
# ['1079470', '851403']
# 10 6
# ['1079470', '851403']
# 11 1
# ['851403', '1079470']
# 11 2
# ['1079470', '851403']
# 11 3
# ['851403', '1079470']
# 11 4
# ['851403', '1079470']
# 11 5
# ['851403', '1079470']
# 11 6
# ['851403', '1079470']
# 12 1
# ['851403', '1079470']
# 12 2
# ['851403', '1079470']
# 12 3
# ['851403', '1079470']
# 12 4
# ['1079470', '851403']
# 12 5
# ['1079470', '851403']
# 12 6
# ['851403', '1079470']
# 13 1
# ['1079470', '290630']
# 13 2
# ['290630', '1079470']
# 13 3
# ['1079470', '290630']
# 13 4
# ['290630', '1079470']
# 13 5
# ['290630', '1079470']
# 13 6
# ['290630', '1079470']
# 14 1
# ['290630', '1079470']
# 14 2
# ['290630', '1079470']
# 14 3
# ['290630', '1079470']
# 14 4
# ['1079470', '290630']
# 14 5
# ['290630', '1079470']
# 14 6
# ['1079470', '290630']
# 15 1
# ['1079470', '290630']
# 15 2
# ['290630', '1079470']
# 15 3
# ['1079470', '290630']
# 15 4
# ['1079470', '290630']
# 15 5
# ['1079470', '290630']
# 15 6
# ['1079470', '290630']
# 16 1
# ['290630', '723105']
# 16 2
# ['290630', '723105']
# 16 3
# ['290630', '723105']
# 16 4
# ['290630', '723105']
# 16 5
# ['290630', '723105']
# 16 6
# ['290630', '723105']
# 17 1
# ['290630', '723105']
# 17 2
# ['290630', '723105']
# 17 3
# ['290630', '723105']
# 17 4
# ['290630', '723105']
# 17 5
# ['290630', '723105']
# 17 6
# ['723105', '290630']
# 18 1
# ['723105', '290630']
# 18 2
# ['723105', '290630']
# 18 3
# ['723105', '290630']
# 18 4
# ['723105', '290630']
# 18 5
# ['290630', '723105']
# 18 6
# ['290630', '723105']
# 19 1
# ['290630', '723105']
# 19 2
# ['723105', '290630']
# 19 3
# ['723105', '290630']
# 19 4
# ['723105', '290630']
# 19 5
# ['723105', '290630']
# 19 6
# ['723105', '290630']
# 20 1
# ['723105', '290630']
# 20 2
# ['723105', '290630']
# 20 3
# ['723105', '290630']
# 20 4
# ['723105', '290630']
# 20 5
# ['723105', '290630']
# 20 6
# ['290630', '723105']
#
# ================================================================================
#                                 MATCH SCORECARD
# ================================================================================
#
# RESULT: Team LSG won by 8 runs runs
# --------------------------------------------------------------------------------
#
# Team LSG INNINGS: 222/2 (20.0 overs)
# --------------------------------------------------------------------------------
# BATSMAN                   STATUS          RUNS     BALLS    4s    6s    SR
# --------------------------------------------------------------------------------
# Abdul Samad               not out         111      58       6     6     191.38
# Nicholas Pooran           out             23       11       2     1     209.09
# Mitchell Marsh            out             64       38       3     3     168.42
# Avesh Khan                not out         19       11       2     0     172.73
# --------------------------------------------------------------------------------
# Extras: 0 (WD: 0, NB: 0, B: 0, LB: 0)
# TOTAL: 222/2 in 20.0 overs
# --------------------------------------------------------------------------------
#
# Team KKR BOWLING:
# BOWLER                    O     M     R     W     ECON
# --------------------------------------------------------------------------------
# Vaibhav Arora             4.0   0     59    1     14.75
# Varun Chakravarthy        4.0   0     39    0     9.75
# Rinku Singh               4.0   0     37    1     9.25
# Anukul Roy                3.0   0     44    0     14.67
# Quinton de Kock           2.0   0     30    0     15.0
# Rovman Powell             1.0   0     6     0     6.0
# Rahmanullah Gurbaz        0.0   0     2     0     0
# ================================================================================
#
# Team KKR INNINGS: 214/4 (19.2 overs)
# --------------------------------------------------------------------------------
# BATSMAN                   STATUS          RUNS     BALLS    4s    6s    SR
# --------------------------------------------------------------------------------
# Angkrish Raghuvanshi      out             41       20       3     1     205.0
# Venkatesh Iyer            out             56       33       3     1     169.7
# Quinton de Kock           out             8        3        0     1     266.67
# Ramandeep Singh           out             36       24       0     1     150.0
# Manish Pandey             not out         35       23       4     0     152.17
# Rinku Singh               not out         28       13       2     1     215.38
# --------------------------------------------------------------------------------
# Extras: 0 (WD: 0, NB: 0, B: 0, LB: 0)
# TOTAL: 214/4 in 19.2 overs
# --------------------------------------------------------------------------------
#
# Team LSG BOWLING:
# BOWLER                    O     M     R     W     ECON
# --------------------------------------------------------------------------------
# Mayank Yadav              4.0   0     42    2     10.5
# Mitchell Marsh            3.0   0     45    0     15.0
# Ravi Bishnoi              3.0   0     27    0     9.0
# Avesh Khan                3.0   0     34    1     11.33
# Akash Singh               1.0   0     24    1     24.0
# Shahbaz Ahmed             1.0   0     9     0     9.0
# Matthew Breetzke          1.0   0     7     0     7.0
# Shardul Thakur            1.0   0     16    0     16.0
# ================================================================================
# [{'match_num': 1,
#   'team1': 'CSK',
#   'team2': 'SRH',
#   'winner': 'SRH',
#   'margin': '10 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 2,
#   'team1': 'GT',
#   'team2': 'MI',
#   'winner': 'GT',
#   'margin': '33 runs',
#   'margin_type': 'runs'},
#  {'match_num': 3,
#   'team1': 'PBKS',
#   'team2': 'RCB',
#   'winner': 'RCB',
#   'margin': '27 runs',
#   'margin_type': 'runs'},
#  {'match_num': 4,
#   'team1': 'GT',
#   'team2': 'SRH',
#   'winner': 'GT',
#   'margin': '9 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 5,
#   'team1': 'LSG',
#   'team2': 'SRH',
#   'winner': 'SRH',
#   'margin': '31 runs',
#   'margin_type': 'runs'},
#  {'match_num': 6,
#   'team1': 'KKR',
#   'team2': 'SRH',
#   'winner': 'SRH',
#   'margin': '7 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 7,
#   'team1': 'CSK',
#   'team2': 'LSG',
#   'winner': 'LSG',
#   'margin': '22 runs',
#   'margin_type': 'runs'},
#  {'match_num': 8,
#   'team1': 'GT',
#   'team2': 'RCB',
#   'winner': 'GT',
#   'margin': '3 runs',
#   'margin_type': 'runs'},
#  {'match_num': 9,
#   'team1': 'KKR',
#   'team2': 'PBKS',
#   'winner': 'KKR',
#   'margin': '31 runs',
#   'margin_type': 'runs'},
#  {'match_num': 10,
#   'team1': 'CSK',
#   'team2': 'RCB',
#   'winner': 'CSK',
#   'margin': '7 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 11,
#   'team1': 'MI',
#   'team2': 'RR',
#   'winner': 'MI',
#   'margin': '6 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 12,
#   'team1': 'DC',
#   'team2': 'KKR',
#   'winner': 'KKR',
#   'margin': '70 runs',
#   'margin_type': 'runs'},
#  {'match_num': 13,
#   'team1': 'MI',
#   'team2': 'SRH',
#   'winner': 'MI',
#   'margin': '6 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 14,
#   'team1': 'KKR',
#   'team2': 'MI',
#   'winner': 'MI',
#   'margin': '8 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 15,
#   'team1': 'CSK',
#   'team2': 'MI',
#   'winner': 'CSK',
#   'margin': '1 runs',
#   'margin_type': 'runs'},
#  {'match_num': 16,
#   'team1': 'DC',
#   'team2': 'GT',
#   'winner': 'GT',
#   'margin': '58 runs',
#   'margin_type': 'runs'},
#  {'match_num': 17,
#   'team1': 'RR',
#   'team2': 'SRH',
#   'winner': 'SRH',
#   'margin': '7 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 18,
#   'team1': 'GT',
#   'team2': 'PBKS',
#   'winner': 'GT',
#   'margin': '46 runs',
#   'margin_type': 'runs'},
#  {'match_num': 19,
#   'team1': 'CSK',
#   'team2': 'KKR',
#   'winner': 'KKR',
#   'margin': '68 runs',
#   'margin_type': 'runs'},
#  {'match_num': 20,
#   'team1': 'PBKS',
#   'team2': 'SRH',
#   'winner': 'SRH',
#   'margin': '13 runs',
#   'margin_type': 'runs'},
#  {'match_num': 21,
#   'team1': 'MI',
#   'team2': 'RCB',
#   'winner': 'MI',
#   'margin': '6 runs',
#   'margin_type': 'runs'},
#  {'match_num': 22,
#   'team1': 'DC',
#   'team2': 'SRH',
#   'winner': 'DC',
#   'margin': '10 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 23,
#   'team1': 'PBKS',
#   'team2': 'RR',
#   'winner': 'RR',
#   'margin': '6 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 24,
#   'team1': 'LSG',
#   'team2': 'RR',
#   'winner': 'RR',
#   'margin': '74 runs',
#   'margin_type': 'runs'},
#  {'match_num': 25,
#   'team1': 'GT',
#   'team2': 'LSG',
#   'winner': 'LSG',
#   'margin': '5 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 26,
#   'team1': 'LSG',
#   'team2': 'MI',
#   'winner': 'MI',
#   'margin': '5 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 27,
#   'team1': 'KKR',
#   'team2': 'RCB',
#   'winner': 'RCB',
#   'margin': '35 runs',
#   'margin_type': 'runs'},
#  {'match_num': 28,
#   'team1': 'CSK',
#   'team2': 'RR',
#   'winner': 'RR',
#   'margin': '5 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 29,
#   'team1': 'KKR',
#   'team2': 'RR',
#   'winner': 'KKR',
#   'margin': '13 runs',
#   'margin_type': 'runs'},
#  {'match_num': 30,
#   'team1': 'LSG',
#   'team2': 'RCB',
#   'winner': 'RCB',
#   'margin': '40 runs',
#   'margin_type': 'runs'},
#  {'match_num': 31,
#   'team1': 'DC',
#   'team2': 'MI',
#   'winner': 'MI',
#   'margin': '39 runs',
#   'margin_type': 'runs'},
#  {'match_num': 32,
#   'team1': 'CSK',
#   'team2': 'PBKS',
#   'winner': 'PBKS',
#   'margin': '3 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 33,
#   'team1': 'RR',
#   'team2': 'RCB',
#   'winner': 'RR',
#   'margin': '24 runs',
#   'margin_type': 'runs'},
#  {'match_num': 34,
#   'team1': 'DC',
#   'team2': 'LSG',
#   'winner': 'DC',
#   'margin': '7 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 35,
#   'team1': 'DC',
#   'team2': 'RCB',
#   'winner': 'RCB',
#   'margin': '16 runs',
#   'margin_type': 'runs'},
#  {'match_num': 36,
#   'team1': 'CSK',
#   'team2': 'DC',
#   'winner': 'CSK',
#   'margin': '29 runs',
#   'margin_type': 'runs'},
#  {'match_num': 37,
#   'team1': 'GT',
#   'team2': 'KKR',
#   'winner': 'KKR',
#   'margin': '7 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 38,
#   'team1': 'DC',
#   'team2': 'PBKS',
#   'winner': 'DC',
#   'margin': '1 runs',
#   'margin_type': 'runs'},
#  {'match_num': 39,
#   'team1': 'RCB',
#   'team2': 'SRH',
#   'winner': 'SRH',
#   'margin': '6 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 40,
#   'team1': 'GT',
#   'team2': 'RR',
#   'winner': 'RR',
#   'margin': '9 runs',
#   'margin_type': 'runs'},
#  {'match_num': 41,
#   'team1': 'DC',
#   'team2': 'RR',
#   'winner': 'RR',
#   'margin': '9 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 42,
#   'team1': 'MI',
#   'team2': 'PBKS',
#   'winner': 'PBKS',
#   'margin': '12 runs',
#   'margin_type': 'runs'},
#  {'match_num': 43,
#   'team1': 'CSK',
#   'team2': 'GT',
#   'winner': 'CSK',
#   'margin': '4 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 44,
#   'team1': 'LSG',
#   'team2': 'PBKS',
#   'winner': 'PBKS',
#   'margin': '5 wickets',
#   'margin_type': 'wickets'},
#  {'match_num': 45,
#   'team1': 'KKR',
#   'team2': 'LSG',
#   'winner': 'LSG',
#   'margin': '8 runs',
#   'margin_type': 'runs'}]

# %%
# Calculate and display standings
standings = simulator.calculate_standings()
simulator.display_league_table(standings)
    
# Print summary of generated BBB data
try:
    bbb_data = pd.read_csv("output/matches/t20_bbb.csv")
    print(f"\nGenerated {len(bbb_data)} ball-by-ball records")
    print(f"Total runs scored: {bbb_data['runs'].sum()}")
    print(f"Total wickets: {bbb_data['is_wicket'].sum()}")
    print(f"Average runs per match: {bbb_data.groupby('match_id')['runs'].sum().mean():.2f}")
except Exception as e:
    print(f"Error reading BBB data: {str(e)}")
# Out:
# ================================================================================
#                                 LEAGUE STANDINGS
# ================================================================================
# TEAM                 P     W     L     PTS   NRR
# --------------------------------------------------------------------------------
# MI                   9     6     3     12    0.000
# RR                   9     6     3     12    0.000
# SRH                  9     6     3     12    0.000
# GT                   9     5     4     10    0.000
# KKR                  9     5     4     10    0.000
# CSK                  9     4     5     8     0.000
# RCB                  9     4     5     8     0.000
# DC                   9     3     6     6     0.000
# LSG                  9     3     6     6     0.000
# PBKS                 9     3     6     6     0.000
# ================================================================================
#
# Generated 10394 ball-by-ball records
# Total runs scored: 18555
# Total wickets: 441
# Average runs per match: 412.33
