# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import logging
import re
from urllib.parse import urljoin

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[logging.FileHandler("iplt20_scraper.log"), logging.StreamHandler()]
)
logger = logging.getLogger(__name__)

class IPLT20Scraper:
    """Simplified scraper for extracting IPL player data from IPLT20.com"""
    
    def __init__(self):
        self.base_url = "https://www.iplt20.com"
        self.teams_url = "https://www.iplt20.com/teams"
        self.session = self._create_session()
        self.teams = []
        self.players = []
        
    def _create_session(self):
        """Create a session with browser-like headers"""
        session = requests.Session()
        
        # Use realistic browser headers
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Language': 'en-US,en;q=0.5',
            'Connection': 'keep-alive',
            'Upgrade-Insecure-Requests': '1',
            'Referer': 'https://www.iplt20.com/',
        }
        session.headers.update(headers)
        
        return session
    
    def get_teams(self):
        """Extract team information from the main teams page"""
        logger.info(f"Fetching teams from {self.teams_url}")
        
        try:
            # Add a small random delay
            time.sleep(1 + random.random())
            
            # Request the teams page
            response = self.session.get(self.teams_url, timeout=30)
            response.raise_for_status()
            
            # Parse the HTML
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Find all team links - based on your provided HTML structure
            team_elements = soup.select('a[onclick="click_teams1(this)"][data-team_name]')
            
            if not team_elements:
                logger.warning("Could not find team elements with primary selector")
                # Try alternative selectors
                team_elements = soup.select('a[data-team_name]')
                
                if not team_elements:
                    team_elements = soup.select('a[href*="/teams/"]')
            
            logger.info(f"Found {len(team_elements)} potential team elements")
            
            # Extract team data
            teams = []
            for element in team_elements:
                try:
                    # Get team URL
                    href = element.get('href')
                    if not href:
                        continue
                    
                    team_url = urljoin(self.base_url, href)
                    
                    # Get team name
                    team_name = element.get('data-team_name')
                    
                    # If data-team_name isn't available, try to find it in the heading
                    if not team_name:
                        heading = element.select_one('h3')
                        if heading:
                            team_name = heading.text.strip()
                    
                    # Skip if we couldn't find a team name
                    if not team_name:
                        continue
                    
                    # Get team logo
                    logo_img = element.select_one('img')
                    logo_url = logo_img.get('src') if logo_img else None
                    
                    # Extract team code
                    team_code = None
                    
                    # Try to get from logo URL
                    if logo_url and 'outline' in logo_url:
                        code_match = re.search(r'/([A-Z]+)outline', logo_url)
                        if code_match:
                            team_code = code_match.group(1)
                    
                    # If not found, try to get from team name
                    if not team_code and team_name:
                        # Extract initials from team name
                        name_parts = team_name.split()
                        if len(name_parts) > 1:
                            team_code = ''.join(part[0].upper() for part in name_parts)
                    
                    # If still not found, try to find in span
                    if not team_code:
                        code_span = element.select_one('.vn-team-logo-onhover span')
                        if code_span:
                            team_code = code_span.text.strip()
                    
                    # Add team info
                    teams.append({
                        'name': team_name,
                        'code': team_code,
                        'url': team_url
                    })
                    
                    logger.info(f"Extracted team: {team_name} ({team_code})")
                    
                except Exception as e:
                    logger.error(f"Error processing team element: {str(e)}")
                    continue
            
            logger.info(f"Successfully extracted {len(teams)} teams")
            self.teams = teams
            return teams
            
        except requests.exceptions.RequestException as e:
            logger.error(f"Failed to retrieve teams page: {str(e)}")
            return []
    
    def get_squad(self, team):
        """Extract squad information for a specific team"""
        team_name = team['name']
        team_url = team['url']
        team_code = team['code']
        
        logger.info(f"Fetching squad for {team_name} from {team_url}")
        
        try:
            # Add delay to avoid rate limiting
            time.sleep(2 + random.random() * 2)
            
            # Request the team page
            response = self.session.get(team_url, timeout=30)
            response.raise_for_status()
            
            # Parse the HTML
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Based on the HTML example you provided, look for player elements
            # using the specific structure
            player_elements = soup.select('a[onclick="click_teams(this)"][data-event_context="player"][data-team_name]')
            
            if not player_elements:
                logger.warning("Could not find player elements with primary selector")
                # Try alternative selectors
                player_elements = soup.select('a[data-player_name]')
                
                if not player_elements:
                    # Look for elements with specific HTML structure we know about
                    player_elements = soup.select('.ih-p-img')
                
                if not player_elements:
                    # Try more general selectors
                    player_elements = soup.select('a[href*="squad-details"]')
            
            logger.info(f"Found {len(player_elements)} potential player elements")
            
            # Extract player data
            players = []
            for element in player_elements:
                try:
                    # Check if we have the original structure (link with onclick) or just the ih-p-img
                    if element.name != 'a' and element.find_parent('a'):
                        element = element.find_parent('a')
                    
                    # Get player name - check from data attribute first
                    player_name = element.get('data-player_name')
                    
                    # If data attribute not available, look for name in heading
                    if not player_name:
                        name_elem = element.select_one('.ih-p-name h2') or element.select_one('h2')
                        if name_elem:
                            player_name = name_elem.text.strip()
                    
                    # Skip if no name found
                    if not player_name:
                        continue
                    
                    # Get player role - based on the span with class="d-block w-100 text-center"
                    role_elem = element.select_one('span.d-block.w-100.text-center') or element.select_one('.ih-p-img span')
                    player_role = role_elem.text.strip() if role_elem else "Unknown"
                    
                    # Get player image
                    img_elem = element.select_one('.ih-p-img img') or element.select_one('img')
                    player_img = None
                    if img_elem:
                        # Try both src and data-src attributes
                        player_img = img_elem.get('src') or img_elem.get('data-src')
                    
                    # Make image URL absolute if it's not
                    if player_img and not player_img.startswith('http'):
                        player_img = urljoin(self.base_url, player_img)
                    
                    # Add player to list
                    players.append({
                        'Name': player_name,
                        'Role': player_role,
                        'Team': team_name,
                        'Team_Code': team_code,
                        'Image_URL': player_img
                    })
                    
                    logger.info(f"Extracted player: {player_name} ({player_role})")
                    
                except Exception as e:
                    logger.error(f"Error extracting player data: {str(e)}")
                    continue
            
            # If we couldn't find any players, try an alternative approach
            if not players:
                logger.warning("Standard approach failed, trying alternative method")
                
                # Look for elements that might contain player images and names
                img_elements = soup.select('img[src*="IPLHeadshot"], img[data-src*="IPLHeadshot"]')
                
                for img in img_elements:
                    try:
                        # Find the parent container that might have player info
                        container = img.find_parent('div', class_='ih-p-img') or img.find_parent('a')
                        
                        if not container:
                            continue
                        
                        # Get player name
                        name_elem = container.select_one('h2')
                        if not name_elem:
                            continue
                            
                        player_name = name_elem.text.strip()
                        
                        # Get player role
                        role_elem = container.select_one('span.d-block')
                        player_role = role_elem.text.strip() if role_elem else "Unknown"
                        
                        # Get image URL
                        player_img = img.get('src') or img.get('data-src')
                        
                        # Make image URL absolute
                        if player_img and not player_img.startswith('http'):
                            player_img = urljoin(self.base_url, player_img)
                        
                        # Add player to list
                        players.append({
                            'Name': player_name,
                            'Role': player_role,
                            'Team': team_name,
                            'Team_Code': team_code,
                            'Image_URL': player_img
                        })
                        
                        logger.info(f"Extracted player (alt method): {player_name} ({player_role})")
                        
                    except Exception as e:
                        logger.error(f"Error in alternative extraction: {str(e)}")
                        continue
            
            logger.info(f"Extracted {len(players)} players for {team_name}")
            return players
            
        except requests.exceptions.RequestException as e:
            logger.error(f"Failed to retrieve squad for {team_name}: {str(e)}")
            return []
    
    def scrape_all_squads(self):
        """Scrape all team squads"""
        # First, get all teams
        teams = self.get_teams()
        
        if not teams:
            logger.error("No teams found!")
            return False
        
        all_players = []
        
        # Now get squad data for each team
        for team in teams:
            players = self.get_squad(team)
            all_players.extend(players)
            
            # Print progress
            logger.info(f"Added {len(players)} players from {team['name']}")
            
            # Add a longer delay between teams
            time.sleep(3 + random.random() * 3)
        
        self.players = all_players
        logger.info(f"Total players collected: {len(all_players)}")
        
        return len(all_players) > 0
    
    def save_data(self):
        """Save the player data to CSV file"""
        if not self.players:
            logger.warning("No player data to save!")
            return False
        
        # Save player data to the requested filename
        players_df = pd.DataFrame(self.players)
        players_df.to_csv("IPL_Squads_List.csv", index=False)
        logger.info("Player data saved to IPL_Squads_List.csv")
        
        return True

def main():
    """Main function to run the scraper"""
    logger.info("Starting IPL squad scraper for IPLT20.com")
    
    scraper = IPLT20Scraper()
    
    # Scrape everything
    teams = scraper.get_teams()
    if teams:
        success = scraper.scrape_all_squads()
        if success:
            scraper.save_data()
            logger.info("Scraping completed successfully")
        else:
            logger.error("Failed to scrape squad data!")
    else:
        logger.error("Failed to retrieve team data!")
    
    logger.info("IPL scraper finished")

if __name__ == "__main__":
    main()
# Out:
# 2025-05-06 15:14:48,306 - INFO - Starting IPL squad scraper for IPLT20.com
# 2025-05-06 15:14:48,306 - INFO - Fetching teams from https://www.iplt20.com/teams
# 2025-05-06 15:14:50,610 - INFO - Found 10 potential team elements
# 2025-05-06 15:14:50,610 - INFO - Extracted team: Chennai Super Kings (CSK)
# 2025-05-06 15:14:50,610 - INFO - Extracted team: Delhi Capitals (DC)
# 2025-05-06 15:14:50,610 - INFO - Extracted team: Gujarat Titans (GT)
# 2025-05-06 15:14:50,610 - INFO - Extracted team: Kolkata Knight Riders (KKR)
# 2025-05-06 15:14:50,610 - INFO - Extracted team: Lucknow Super Giants (LSG)
# 2025-05-06 15:14:50,610 - INFO - Extracted team: Mumbai Indians (MI)
# 2025-05-06 15:14:50,610 - INFO - Extracted team: Punjab Kings (PBKS)
# 2025-05-06 15:14:50,610 - INFO - Extracted team: Rajasthan Royals (RR)
# 2025-05-06 15:14:50,626 - INFO - Extracted team: Royal Challengers Bengaluru (RCB)
# 2025-05-06 15:14:50,628 - INFO - Extracted team: Sunrisers Hyderabad (SRH)
# 2025-05-06 15:14:50,632 - INFO - Successfully extracted 10 teams
# 2025-05-06 15:14:50,632 - INFO - Fetching teams from https://www.iplt20.com/teams
# 2025-05-06 15:14:52,465 - INFO - Found 10 potential team elements
# 2025-05-06 15:14:52,465 - INFO - Extracted team: Chennai Super Kings (CSK)
# 2025-05-06 15:14:52,465 - INFO - Extracted team: Delhi Capitals (DC)
# 2025-05-06 15:14:52,465 - INFO - Extracted team: Gujarat Titans (GT)
# 2025-05-06 15:14:52,481 - INFO - Extracted team: Kolkata Knight Riders (KKR)
# 2025-05-06 15:14:52,481 - INFO - Extracted team: Lucknow Super Giants (LSG)
# 2025-05-06 15:14:52,481 - INFO - Extracted team: Mumbai Indians (MI)
# 2025-05-06 15:14:52,481 - INFO - Extracted team: Punjab Kings (PBKS)
# 2025-05-06 15:14:52,481 - INFO - Extracted team: Rajasthan Royals (RR)
# 2025-05-06 15:14:52,492 - INFO - Extracted team: Royal Challengers Bengaluru (RCB)
# 2025-05-06 15:14:52,494 - INFO - Extracted team: Sunrisers Hyderabad (SRH)
# 2025-05-06 15:14:52,496 - INFO - Successfully extracted 10 teams
# 2025-05-06 15:14:52,497 - INFO - Fetching squad for Chennai Super Kings from https://www.iplt20.com/teams/chennai-super-kings
# 2025-05-06 15:14:56,487 - INFO - Found 26 potential player elements
# 2025-05-06 15:14:56,487 - INFO - Extracted player: MS Dhoni (WK-Batter)
# 2025-05-06 15:14:56,495 - INFO - Extracted player: Dewald Brevis (Batter)
# 2025-05-06 15:14:56,497 - INFO - Extracted player: Devon Conway (Batter)
# 2025-05-06 15:14:56,501 - INFO - Extracted player: Rahul Tripathi (Batter)
# 2025-05-06 15:14:56,501 - INFO - Extracted player: Shaik Rasheed (Batter)
# 2025-05-06 15:14:56,501 - INFO - Extracted player: Vansh Bedi (WK-Batter)
# 2025-05-06 15:14:56,501 - INFO - Extracted player: Andre Siddarth (Batter)
# 2025-05-06 15:14:56,511 - INFO - Extracted player: Ayush Mhatre (Batter)
# 2025-05-06 15:14:56,511 - INFO - Extracted player: Urvil Patel (WK-Batter)
# 2025-05-06 15:14:56,516 - INFO - Extracted player: Rachin Ravindra (All-Rounder)
# 2025-05-06 15:14:56,517 - INFO - Extracted player: Ravichandran Ashwin (All-Rounder)
# 2025-05-06 15:14:56,519 - INFO - Extracted player: Vijay Shankar (All-Rounder)
# 2025-05-06 15:14:56,519 - INFO - Extracted player: Sam Curran (All-Rounder)
# 2025-05-06 15:14:56,523 - INFO - Extracted player: Anshul Kamboj (All-Rounder)
# 2025-05-06 15:14:56,523 - INFO - Extracted player: Deepak Hooda (All-Rounder)
# 2025-05-06 15:14:56,523 - INFO - Extracted player: Jamie Overton (All-Rounder)
# 2025-05-06 15:14:56,530 - INFO - Extracted player: Kamlesh Nagarkoti (All-Rounder)
# 2025-05-06 15:14:56,535 - INFO - Extracted player: Ramakrishna Ghosh (All-Rounder)
# 2025-05-06 15:14:56,538 - INFO - Extracted player: Ravindra Jadeja (All-Rounder)
# 2025-05-06 15:14:56,539 - INFO - Extracted player: Shivam Dube (All-Rounder)
# 2025-05-06 15:14:56,539 - INFO - Extracted player: Khaleel Ahmed (Bowler)
# 2025-05-06 15:14:56,543 - INFO - Extracted player: Noor Ahmad (Bowler)
# 2025-05-06 15:14:56,543 - INFO - Extracted player: Mukesh Choudhary (Bowler)
# 2025-05-06 15:14:56,548 - INFO - Extracted player: Nathan Ellis (Bowler)
# 2025-05-06 15:14:56,548 - INFO - Extracted player: Shreyas Gopal (Bowler)
# 2025-05-06 15:14:56,548 - INFO - Extracted player: Matheesha Pathirana (Bowler)
# 2025-05-06 15:14:56,548 - INFO - Extracted 26 players for Chennai Super Kings
# 2025-05-06 15:14:56,548 - INFO - Added 26 players from Chennai Super Kings
# 2025-05-06 15:15:00,275 - INFO - Fetching squad for Delhi Capitals from https://www.iplt20.com/teams/delhi-capitals
# 2025-05-06 15:15:04,386 - INFO - Found 22 potential player elements
# 2025-05-06 15:15:04,387 - INFO - Extracted player: KL Rahul (WK-Batter)
# 2025-05-06 15:15:04,387 - INFO - Extracted player: Jake Fraser-McGurk (Batter)
# 2025-05-06 15:15:04,396 - INFO - Extracted player: Karun Nair (Batter)
# 2025-05-06 15:15:04,396 - INFO - Extracted player: Faf du Plessis (Batter)
# 2025-05-06 15:15:04,396 - INFO - Extracted player: Donovan Ferreira (WK-Batter)
# 2025-05-06 15:15:04,405 - INFO - Extracted player: Abishek Porel (WK-Batter)
# 2025-05-06 15:15:04,408 - INFO - Extracted player: Tristan Stubbs (WK-Batter)
# 2025-05-06 15:15:04,412 - INFO - Extracted player: Axar Patel (All-Rounder)
# 2025-05-06 15:15:04,415 - INFO - Extracted player: Sameer Rizvi (All-Rounder)
# 2025-05-06 15:15:04,418 - INFO - Extracted player: Ashutosh Sharma (All-Rounder)
# 2025-05-06 15:15:04,421 - INFO - Extracted player: Darshan Nalkande (All-Rounder)
# 2025-05-06 15:15:04,421 - INFO - Extracted player: Vipraj Nigam (All-Rounder)
# 2025-05-06 15:15:04,426 - INFO - Extracted player: Ajay Mandal (All-Rounder)
# 2025-05-06 15:15:04,431 - INFO - Extracted player: Manvanth Kumar (All-Rounder)
# 2025-05-06 15:15:04,431 - INFO - Extracted player: Tripurana Vijay (All-Rounder)
# 2025-05-06 15:15:04,431 - INFO - Extracted player: Madhav Tiwari (All-Rounder)
# 2025-05-06 15:15:04,431 - INFO - Extracted player: Mitchell Starc (Bowler)
# 2025-05-06 15:15:04,444 - INFO - Extracted player: T. Natarajan (Bowler)
# 2025-05-06 15:15:04,444 - INFO - Extracted player: Mohit Sharma (Bowler)
# 2025-05-06 15:15:04,450 - INFO - Extracted player: Mukesh Kumar (Bowler)
# 2025-05-06 15:15:04,451 - INFO - Extracted player: Dushmantha Chameera (Bowler)
# 2025-05-06 15:15:04,451 - INFO - Extracted player: Kuldeep Yadav (Bowler)
# 2025-05-06 15:15:04,451 - INFO - Extracted 22 players for Delhi Capitals
# 2025-05-06 15:15:04,460 - INFO - Added 22 players from Delhi Capitals
# 2025-05-06 15:15:08,657 - INFO - Fetching squad for Gujarat Titans from https://www.iplt20.com/teams/gujarat-titans
# 2025-05-06 15:15:11,978 - INFO - Found 25 potential player elements
# 2025-05-06 15:15:11,978 - INFO - Extracted player: Shubman Gill (Batter)
# 2025-05-06 15:15:11,978 - INFO - Extracted player: Jos Buttler (WK-Batter)
# 2025-05-06 15:15:11,994 - INFO - Extracted player: Kumar Kushagra (WK-Batter)
# 2025-05-06 15:15:11,994 - INFO - Extracted player: Anuj Rawat (WK-Batter)
# 2025-05-06 15:15:11,994 - INFO - Extracted player: Sherfane Rutherford (Batter)
# 2025-05-06 15:15:11,994 - INFO - Extracted player: Nishant Sindhu (All-Rounder)
# 2025-05-06 15:15:11,994 - INFO - Extracted player: Mahipal Lomror (All-Rounder)
# 2025-05-06 15:15:12,003 - INFO - Extracted player: Washington Sundar (All-Rounder)
# 2025-05-06 15:15:12,008 - INFO - Extracted player: Mohd. Arshad Khan (All-Rounder)
# 2025-05-06 15:15:12,012 - INFO - Extracted player: Sai Kishore (All-Rounder)
# 2025-05-06 15:15:12,012 - INFO - Extracted player: Jayant Yadav (All-Rounder)
# 2025-05-06 15:15:12,020 - INFO - Extracted player: Karim Janat (All-Rounder)
# 2025-05-06 15:15:12,020 - INFO - Extracted player: Sai Sudharsan (All-Rounder)
# 2025-05-06 15:15:12,026 - INFO - Extracted player: Dasun shanaka (All-Rounder)
# 2025-05-06 15:15:12,032 - INFO - Extracted player: Shahrukh Khan (All-Rounder)
# 2025-05-06 15:15:12,036 - INFO - Extracted player: Kagiso Rabada (Bowler)
# 2025-05-06 15:15:12,039 - INFO - Extracted player: Mohammed Siraj (Bowler)
# 2025-05-06 15:15:12,039 - INFO - Extracted player: Prasidh Krishna (Bowler)
# 2025-05-06 15:15:12,044 - INFO - Extracted player: Manav Suthar (Bowler)
# 2025-05-06 15:15:12,048 - INFO - Extracted player: Gerald Coetzee (Bowler)
# 2025-05-06 15:15:12,048 - INFO - Extracted player: Gurnoor Singh Brar (Bowler)
# 2025-05-06 15:15:12,053 - INFO - Extracted player: Ishant Sharma (Bowler)
# 2025-05-06 15:15:12,055 - INFO - Extracted player: Kulwant Khejroliya (Bowler)
# 2025-05-06 15:15:12,055 - INFO - Extracted player: Rahul Tewatia (Bowler)
# 2025-05-06 15:15:12,055 - INFO - Extracted player: Rashid Khan (Bowler)
# 2025-05-06 15:15:12,062 - INFO - Extracted 25 players for Gujarat Titans
# 2025-05-06 15:15:12,064 - INFO - Added 25 players from Gujarat Titans
# 2025-05-06 15:15:17,370 - INFO - Fetching squad for Kolkata Knight Riders from https://www.iplt20.com/teams/kolkata-knight-riders
# 2025-05-06 15:15:20,367 - INFO - Found 21 potential player elements
# 2025-05-06 15:15:20,367 - INFO - Extracted player: Ajinkya Rahane (Batter)
# 2025-05-06 15:15:20,378 - INFO - Extracted player: Rinku Singh (Batter)
# 2025-05-06 15:15:20,381 - INFO - Extracted player: Quinton de Kock (WK-Batter)
# 2025-05-06 15:15:20,383 - INFO - Extracted player: Rahmanullah Gurbaz (WK-Batter)
# 2025-05-06 15:15:20,388 - INFO - Extracted player: Angkrish Raghuvanshi (Batter)
# 2025-05-06 15:15:20,388 - INFO - Extracted player: Rovman Powell (Batter)
# 2025-05-06 15:15:20,394 - INFO - Extracted player: Manish Pandey (Batter)
# 2025-05-06 15:15:20,394 - INFO - Extracted player: Luvnith Sisodia (WK-Batter)
# 2025-05-06 15:15:20,400 - INFO - Extracted player: Venkatesh Iyer (All-Rounder)
# 2025-05-06 15:15:20,405 - INFO - Extracted player: Anukul Roy (All-Rounder)
# 2025-05-06 15:15:20,407 - INFO - Extracted player: Moeen Ali (All-Rounder)
# 2025-05-06 15:15:20,410 - INFO - Extracted player: Ramandeep Singh (All-Rounder)
# 2025-05-06 15:15:20,410 - INFO - Extracted player: Andre Russell (All-Rounder)
# 2025-05-06 15:15:20,414 - INFO - Extracted player: Anrich Nortje (Bowler)
# 2025-05-06 15:15:20,414 - INFO - Extracted player: Vaibhav Arora (Bowler)
# 2025-05-06 15:15:20,414 - INFO - Extracted player: Mayank Markande (Bowler)
# 2025-05-06 15:15:20,426 - INFO - Extracted player: Spencer Johnson (Bowler)
# 2025-05-06 15:15:20,427 - INFO - Extracted player: Harshit Rana (Bowler)
# 2025-05-06 15:15:20,433 - INFO - Extracted player: Sunil Narine (Bowler)
# 2025-05-06 15:15:20,434 - INFO - Extracted player: Varun Chakaravarthy (Bowler)
# 2025-05-06 15:15:20,434 - INFO - Extracted player: Chetan Sakariya (Bowler)
# 2025-05-06 15:15:20,441 - INFO - Extracted 21 players for Kolkata Knight Riders
# 2025-05-06 15:15:20,441 - INFO - Added 21 players from Kolkata Knight Riders
# 2025-05-06 15:15:23,724 - INFO - Fetching squad for Lucknow Super Giants from https://www.iplt20.com/teams/lucknow-super-giants
# 2025-05-06 15:15:26,905 - INFO - Found 24 potential player elements
# 2025-05-06 15:15:26,905 - INFO - Extracted player: Rishabh Pant (WK-Batter)
# 2025-05-06 15:15:26,905 - INFO - Extracted player: David Miller (Batter)
# 2025-05-06 15:15:26,905 - INFO - Extracted player: Aiden Markram (Batter)
# 2025-05-06 15:15:26,905 - INFO - Extracted player: Aryan Juyal (WK-Batter)
# 2025-05-06 15:15:26,920 - INFO - Extracted player: Himmat Singh (Batter)
# 2025-05-06 15:15:26,920 - INFO - Extracted player: Matthew Breetzke (Batter)
# 2025-05-06 15:15:26,920 - INFO - Extracted player: Nicholas Pooran (WK-Batter)
# 2025-05-06 15:15:26,927 - INFO - Extracted player: Mitchell Marsh (All-Rounder)
# 2025-05-06 15:15:26,930 - INFO - Extracted player: Abdul Samad (All-Rounder)
# 2025-05-06 15:15:26,932 - INFO - Extracted player: Shahbaz Ahamad (All-Rounder)
# 2025-05-06 15:15:26,932 - INFO - Extracted player: Yuvraj Chaudhary (All-Rounder)
# 2025-05-06 15:15:26,932 - INFO - Extracted player: Rajvardhan Hangargekar (All-Rounder)
# 2025-05-06 15:15:26,932 - INFO - Extracted player: Arshin Kulkarni (All-Rounder)
# 2025-05-06 15:15:26,932 - INFO - Extracted player: Ayush Badoni (All-Rounder)
# 2025-05-06 15:15:26,932 - INFO - Extracted player: Shardul Thakur (All-Rounder)
# 2025-05-06 15:15:26,943 - INFO - Extracted player: Avesh Khan (Bowler)
# 2025-05-06 15:15:26,948 - INFO - Extracted player: Akash Deep (Bowler)
# 2025-05-06 15:15:26,948 - INFO - Extracted player: M. Siddharth (Bowler)
# 2025-05-06 15:15:26,951 - INFO - Extracted player: Digvesh Singh (Bowler)
# 2025-05-06 15:15:26,953 - INFO - Extracted player: Akash Singh (Bowler)
# 2025-05-06 15:15:26,954 - INFO - Extracted player: Shamar Joseph (Bowler)
# 2025-05-06 15:15:26,960 - INFO - Extracted player: Prince Yadav (Bowler)
# 2025-05-06 15:15:26,960 - INFO - Extracted player: Mayank Yadav (Bowler)
# 2025-05-06 15:15:26,963 - INFO - Extracted player: Ravi Bishnoi (Bowler)
# 2025-05-06 15:15:26,968 - INFO - Extracted 24 players for Lucknow Super Giants
# 2025-05-06 15:15:26,970 - INFO - Added 24 players from Lucknow Super Giants
# 2025-05-06 15:15:30,093 - INFO - Fetching squad for Mumbai Indians from https://www.iplt20.com/teams/mumbai-indians
# 2025-05-06 15:15:33,077 - INFO - Found 23 potential player elements
# 2025-05-06 15:15:33,077 - INFO - Extracted player: Rohit Sharma (Batter)
# 2025-05-06 15:15:33,077 - INFO - Extracted player: Surya Kumar Yadav (Batter)
# 2025-05-06 15:15:33,077 - INFO - Extracted player: Robin Minz (WK-Batter)
# 2025-05-06 15:15:33,089 - INFO - Extracted player: Ryan Rickelton (WK-Batter)
# 2025-05-06 15:15:33,093 - INFO - Extracted player: Shrijith Krishnan (WK-Batter)
# 2025-05-06 15:15:33,093 - INFO - Extracted player: Bevon Jacobs (Batter)
# 2025-05-06 15:15:33,093 - INFO - Extracted player: N. Tilak Varma (Batter)
# 2025-05-06 15:15:33,098 - INFO - Extracted player: Hardik Pandya (All-Rounder)
# 2025-05-06 15:15:33,098 - INFO - Extracted player: Naman Dhir (All-Rounder)
# 2025-05-06 15:15:33,100 - INFO - Extracted player: Will Jacks (All-Rounder)
# 2025-05-06 15:15:33,103 - INFO - Extracted player: Mitchell Santner (All-Rounder)
# 2025-05-06 15:15:33,107 - INFO - Extracted player: Raj Angad Bawa (All-Rounder)
# 2025-05-06 15:15:33,107 - INFO - Extracted player: Corbin Bosch (All-Rounder)
# 2025-05-06 15:15:33,111 - INFO - Extracted player: Trent Boult (Bowler)
# 2025-05-06 15:15:33,114 - INFO - Extracted player: Karn Sharma (Bowler)
# 2025-05-06 15:15:33,114 - INFO - Extracted player: Deepak Chahar (Bowler)
# 2025-05-06 15:15:33,114 - INFO - Extracted player: Ashwani Kumar (Bowler)
# 2025-05-06 15:15:33,114 - INFO - Extracted player: Reece Topley (Bowler)
# 2025-05-06 15:15:33,114 - INFO - Extracted player: V.Satyanarayana Penmetsa (Bowler)
# 2025-05-06 15:15:33,122 - INFO - Extracted player: Arjun Tendulkar (Bowler)
# 2025-05-06 15:15:33,125 - INFO - Extracted player: Mujeeb-ur-Rahman (Bowler)
# 2025-05-06 15:15:33,126 - INFO - Extracted player: Raghu Sharma (Bowler)
# 2025-05-06 15:15:33,131 - INFO - Extracted player: Jasprit Bumrah (Bowler)
# 2025-05-06 15:15:33,133 - INFO - Extracted 23 players for Mumbai Indians
# 2025-05-06 15:15:33,133 - INFO - Added 23 players from Mumbai Indians
# 2025-05-06 15:15:37,167 - INFO - Fetching squad for Punjab Kings from https://www.iplt20.com/teams/punjab-kings
# 2025-05-06 15:15:41,150 - INFO - Found 25 potential player elements
# 2025-05-06 15:15:41,150 - INFO - Extracted player: Shreyas Iyer (Batter)
# 2025-05-06 15:15:41,160 - INFO - Extracted player: Nehal Wadhera (Batter)
# 2025-05-06 15:15:41,160 - INFO - Extracted player: Vishnu Vinod (WK-Batter)
# 2025-05-06 15:15:41,160 - INFO - Extracted player: Josh Inglis (WK-Batter)
# 2025-05-06 15:15:41,160 - INFO - Extracted player: Harnoor Pannu (Batter)
# 2025-05-06 15:15:41,160 - INFO - Extracted player: Pyla Avinash (Batter)
# 2025-05-06 15:15:41,171 - INFO - Extracted player: Prabhsimran Singh (WK-Batter)
# 2025-05-06 15:15:41,174 - INFO - Extracted player: Shashank Singh (Batter)
# 2025-05-06 15:15:41,175 - INFO - Extracted player: Marcus Stoinis (All-Rounder)
# 2025-05-06 15:15:41,179 - INFO - Extracted player: Harpreet Brar (All-Rounder)
# 2025-05-06 15:15:41,179 - INFO - Extracted player: Marco Jansen (All-Rounder)
# 2025-05-06 15:15:41,179 - INFO - Extracted player: Azmatullah Omarzai (All-Rounder)
# 2025-05-06 15:15:41,179 - INFO - Extracted player: Priyansh Arya (All-Rounder)
# 2025-05-06 15:15:41,191 - INFO - Extracted player: Aaron Hardie (All-Rounder)
# 2025-05-06 15:15:41,192 - INFO - Extracted player: Musheer Khan (All-Rounder)
# 2025-05-06 15:15:41,198 - INFO - Extracted player: Suryansh Shedge (All-Rounder)
# 2025-05-06 15:15:41,198 - INFO - Extracted player: Mitch Owen (Batter)
# 2025-05-06 15:15:41,204 - INFO - Extracted player: Arshdeep Singh (Bowler)
# 2025-05-06 15:15:41,204 - INFO - Extracted player: Yuzvendra Chahal (Bowler)
# 2025-05-06 15:15:41,204 - INFO - Extracted player: Vyshak Vijaykumar (Bowler)
# 2025-05-06 15:15:41,204 - INFO - Extracted player: Yash Thakur (Bowler)
# 2025-05-06 15:15:41,215 - INFO - Extracted player: Lockie Ferguson (Bowler)
# 2025-05-06 15:15:41,215 - INFO - Extracted player: Kuldeep Sen (Bowler)
# 2025-05-06 15:15:41,215 - INFO - Extracted player: Xavier Bartlett (Bowler)
# 2025-05-06 15:15:41,226 - INFO - Extracted player: Pravin Dubey (Bowler)
# 2025-05-06 15:15:41,226 - INFO - Extracted 25 players for Punjab Kings
# 2025-05-06 15:15:41,226 - INFO - Added 25 players from Punjab Kings
# 2025-05-06 15:15:45,378 - INFO - Fetching squad for Rajasthan Royals from https://www.iplt20.com/teams/rajasthan-royals
# 2025-05-06 15:15:48,404 - INFO - Found 20 potential player elements
# 2025-05-06 15:15:48,407 - INFO - Extracted player: Sanju Samson (WK-Batter)
# 2025-05-06 15:15:48,409 - INFO - Extracted player: Shubham Dubey (Batter)
# 2025-05-06 15:15:48,409 - INFO - Extracted player: Vaibhav Suryavanshi (Batter)
# 2025-05-06 15:15:48,413 - INFO - Extracted player: Kunal Rathore (WK-Batter)
# 2025-05-06 15:15:48,417 - INFO - Extracted player: Shimron Hetmyer (Batter)
# 2025-05-06 15:15:48,419 - INFO - Extracted player: Yashasvi Jaiswal (Batter)
# 2025-05-06 15:15:48,421 - INFO - Extracted player: Dhruv Jurel (WK-Batter)
# 2025-05-06 15:15:48,426 - INFO - Extracted player: Riyan Parag (Batter)
# 2025-05-06 15:15:48,429 - INFO - Extracted player: Nitish Rana (All-Rounder)
# 2025-05-06 15:15:48,432 - INFO - Extracted player: Yudhvir Singh Charak (All-Rounder)
# 2025-05-06 15:15:48,432 - INFO - Extracted player: Jofra Archer (Bowler)
# 2025-05-06 15:15:48,440 - INFO - Extracted player: Maheesh Theekshana (Bowler)
# 2025-05-06 15:15:48,443 - INFO - Extracted player: Wanindu Hasaranga (Bowler)
# 2025-05-06 15:15:48,443 - INFO - Extracted player: Akash Madhwal (Bowler)
# 2025-05-06 15:15:48,448 - INFO - Extracted player: Kumar Kartikeya Singh (Bowler)
# 2025-05-06 15:15:48,450 - INFO - Extracted player: Tushar Deshpande (Bowler)
# 2025-05-06 15:15:48,452 - INFO - Extracted player: Fazalhaq Farooqi (Bowler)
# 2025-05-06 15:15:48,460 - INFO - Extracted player: Kwena Maphaka (Bowler)
# 2025-05-06 15:15:48,460 - INFO - Extracted player: Ashok Sharma (Bowler)
# 2025-05-06 15:15:48,464 - INFO - Extracted player: Sandeep Sharma (Bowler)
# 2025-05-06 15:15:48,468 - INFO - Extracted 20 players for Rajasthan Royals
# 2025-05-06 15:15:48,468 - INFO - Added 20 players from Rajasthan Royals
# 2025-05-06 15:15:52,416 - INFO - Fetching squad for Royal Challengers Bengaluru from https://www.iplt20.com/teams/royal-challengers-bengaluru
# 2025-05-06 15:15:55,368 - INFO - Found 22 potential player elements
# 2025-05-06 15:15:55,368 - INFO - Extracted player: Rajat Patidar (Batter)
# 2025-05-06 15:15:55,368 - INFO - Extracted player: Virat Kohli (Batter)
# 2025-05-06 15:15:55,368 - INFO - Extracted player: Phil Salt (WK-Batter)
# 2025-05-06 15:15:55,384 - INFO - Extracted player: Jitesh Sharma (WK-Batter)
# 2025-05-06 15:15:55,384 - INFO - Extracted player: Devdutt Padikkal (Batter)
# 2025-05-06 15:15:55,384 - INFO - Extracted player: Swastik Chhikara (Batter)
# 2025-05-06 15:15:55,384 - INFO - Extracted player: Liam Livingstone (All-Rounder)
# 2025-05-06 15:15:55,384 - INFO - Extracted player: Krunal Pandya (All-Rounder)
# 2025-05-06 15:15:55,384 - INFO - Extracted player: Swapnil Singh (All-Rounder)
# 2025-05-06 15:15:55,384 - INFO - Extracted player: Tim David (All-Rounder)
# 2025-05-06 15:15:55,400 - INFO - Extracted player: Romario Shepherd (All-Rounder)
# 2025-05-06 15:15:55,400 - INFO - Extracted player: Manoj Bhandage (All-Rounder)
# 2025-05-06 15:15:55,400 - INFO - Extracted player: Jacob Bethell (All-Rounder)
# 2025-05-06 15:15:55,400 - INFO - Extracted player: Josh Hazlewood (Bowler)
# 2025-05-06 15:15:55,400 - INFO - Extracted player: Rasikh Dar (Bowler)
# 2025-05-06 15:15:55,400 - INFO - Extracted player: Suyash Sharma (Bowler)
# 2025-05-06 15:15:55,400 - INFO - Extracted player: Bhuvneshwar Kumar (Bowler)
# 2025-05-06 15:15:55,400 - INFO - Extracted player: Nuwan Thushara (Bowler)
# 2025-05-06 15:15:55,416 - INFO - Extracted player: Lungisani Ngidi (Bowler)
# 2025-05-06 15:15:55,416 - INFO - Extracted player: Abhinandan Singh (Bowler)
# 2025-05-06 15:15:55,416 - INFO - Extracted player: Mohit Rathee (Bowler)
# 2025-05-06 15:15:55,423 - INFO - Extracted player: Yash Dayal (Bowler)
# 2025-05-06 15:15:55,425 - INFO - Extracted 22 players for Royal Challengers Bengaluru
# 2025-05-06 15:15:55,425 - INFO - Added 22 players from Royal Challengers Bengaluru
# 2025-05-06 15:16:00,294 - INFO - Fetching squad for Sunrisers Hyderabad from https://www.iplt20.com/teams/sunrisers-hyderabad
# 2025-05-06 15:16:04,158 - INFO - Found 21 potential player elements
# 2025-05-06 15:16:04,158 - INFO - Extracted player: Ishan Kishan (WK-Batter)
# 2025-05-06 15:16:04,164 - INFO - Extracted player: Atharva Taide (Batter)
# 2025-05-06 15:16:04,164 - INFO - Extracted player: Abhinav Manohar (Batter)
# 2025-05-06 15:16:04,164 - INFO - Extracted player: Aniket Verma (Batter)
# 2025-05-06 15:16:04,172 - INFO - Extracted player: Sachin Baby (Batter)
# 2025-05-06 15:16:04,172 - INFO - Extracted player: Smaran Ravichandran (Batter)
# 2025-05-06 15:16:04,178 - INFO - Extracted player: Heinrich Klaasen (WK-Batter)
# 2025-05-06 15:16:04,180 - INFO - Extracted player: Travis Head (Batter)
# 2025-05-06 15:16:04,180 - INFO - Extracted player: Harshal Patel (All-Rounder)
# 2025-05-06 15:16:04,188 - INFO - Extracted player: Kamindu Mendis (All-Rounder)
# 2025-05-06 15:16:04,192 - INFO - Extracted player: Wiaan Mulder (All-Rounder)
# 2025-05-06 15:16:04,192 - INFO - Extracted player: Harsh Dubey (All-Rounder)
# 2025-05-06 15:16:04,192 - INFO - Extracted player: Abhishek Sharma (All-Rounder)
# 2025-05-06 15:16:04,196 - INFO - Extracted player: Nitish Kumar Reddy (All-Rounder)
# 2025-05-06 15:16:04,196 - INFO - Extracted player: Pat Cummins (Bowler)
# 2025-05-06 15:16:04,196 - INFO - Extracted player: Mohammad Shami (Bowler)
# 2025-05-06 15:16:04,196 - INFO - Extracted player: Rahul Chahar (Bowler)
# 2025-05-06 15:16:04,204 - INFO - Extracted player: Simarjeet Singh (Bowler)
# 2025-05-06 15:16:04,208 - INFO - Extracted player: Zeeshan Ansari (Bowler)
# 2025-05-06 15:16:04,208 - INFO - Extracted player: Jaydev Unadkat (Bowler)
# 2025-05-06 15:16:04,208 - INFO - Extracted player: Eshan Malinga (Bowler)
# 2025-05-06 15:16:04,208 - INFO - Extracted 21 players for Sunrisers Hyderabad
# 2025-05-06 15:16:04,220 - INFO - Added 21 players from Sunrisers Hyderabad
# 2025-05-06 15:16:09,468 - INFO - Total players collected: 229
# 2025-05-06 15:16:09,474 - INFO - Player data saved to IPL_Squads_List.csv
# 2025-05-06 15:16:09,476 - INFO - Scraping completed successfully
# 2025-05-06 15:16:09,476 - INFO - IPL scraper finished
